# %% [markdown]
# **Genome-wide assessment identifies novel runs of homozygosity linked to Parkinson’s disease etiology across diverse ancestral populations**
#
# ---
#
# *   **Project:** Runs of Homozygosity (ROH) Analysis in Parkinson's Disease
# *   **Version:** Python/3.9
# *   **Authors**: Kathryn Step, Carlos F. Hernández, Esraa Eltaraifee, Ana Jimena Hernández-Medrano, Pin-Jui Kung, Miriam Ostrožovičová, Alexandra Zirra, Zih-Hua Fang and Sara Bandres-Ciga
# *   **Estimated Computation and Runtime**:
#    *   **Estimated Specifications:**  1 CPU, 7.5 GB Memory, 100 GB Persistent Disk Size
#    *   **Estimated Runtime:** 120 min
# *   **Status:** COMPLETE
# *   **Started:** 26-AUG-2023
# *   **Last Updated:** 24-NOV-2024
#    *   **Update Description:** Completed statistical modeling of ROH burden and generated population-specific results
#
# ---
#
# **Notebook Overview**
# *   Statistical analysis of ROH burden across populations
# *   Comparing ROH metrics (e.g., total ROH length, number of ROH segments, genomic inbreeding coefficient) between Parkinson's disease cases and controls
# *   Performing regression and t-tests for Early-Onset Parkinson’s Disease (EOPD) and Late-Onset Parkinson’s Disease (LOPD) subsets
# *   Evaluating ROH-based differences across ancestries and performing statistical corrections
#
# ---

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Getting-Started" data-toc-modified-id="Getting-Started-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Getting Started</a></span></li><li><span><a href="#Create-Working-Directory" data-toc-modified-id="Create-Working-Directory-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Create Working Directory</a></span></li><li><span><a href="#Summary-Results" data-toc-modified-id="Summary-Results-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Summary Results</a></span><ul class="toc-item"><li><span><a href="#Count-ROH" data-toc-modified-id="Count-ROH-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Count ROH</a></span></li><li><span><a href="#Percentage-with-ROH" data-toc-modified-id="Percentage-with-ROH-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Percentage with ROH</a></span></li><li><span><a href="#FROH-in-all-ancestries" data-toc-modified-id="FROH-in-all-ancestries-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>FROH in all ancestries</a></span></li><li><span><a href="#Figure-3" data-toc-modified-id="Figure-3-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Figure 3</a></span><ul class="toc-item"><li><span><a href="#Mean-values" data-toc-modified-id="Mean-values-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Mean values</a></span></li><li><span><a href="#Individual-values" data-toc-modified-id="Individual-values-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Individual values</a></span></li></ul></li></ul></li><li><span><a href="#Inbreeding-Coefficient-Plots" data-toc-modified-id="Inbreeding-Coefficient-Plots-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Inbreeding Coefficient Plots</a></span><ul class="toc-item"><li><span><a href="#Plot" data-toc-modified-id="Plot-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Plot</a></span><ul class="toc-item"><li><span><a href="#Figure-4A---All-Individuals" data-toc-modified-id="Figure-4A---All-Individuals-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Figure 4A - All Individuals</a></span></li><li><span><a href="#Figure-4B---Only-Cases" data-toc-modified-id="Figure-4B---Only-Cases-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Figure 4B - Only Cases</a></span></li><li><span><a href="#Figure-4C---Only-Controls" data-toc-modified-id="Figure-4C---Only-Controls-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Figure 4C - Only Controls</a></span></li></ul></li></ul></li><li><span><a href="#Suppl.-Figure-1---Scree-Plots" data-toc-modified-id="Suppl.-Figure-1---Scree-Plots-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Suppl. Figure 1 - Scree Plots</a></span></li><li><span><a href="#ROH-Parameters-Plots" data-toc-modified-id="ROH-Parameters-Plots-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>ROH Parameters Plots</a></span><ul class="toc-item"><li><span><a href="#Find-better-range-of-data" data-toc-modified-id="Find-better-range-of-data-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Find better range of data</a></span></li><li><span><a href="#Suppl.-Figure-2---KB-(SROH)-vs.-NSEG-(NROH)-Plots-with-fixed-axis" data-toc-modified-id="Suppl.-Figure-2---KB-(SROH)-vs.-NSEG-(NROH)-Plots-with-fixed-axis-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Suppl. Figure 2 - KB (SROH) vs. NSEG (NROH) Plots with fixed axis</a></span></li><li><span><a href="#Suppl.-Figure-3---AVROH-vs.-NROH-Plots" data-toc-modified-id="Suppl.-Figure-3---AVROH-vs.-NROH-Plots-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Suppl. Figure 3 - AVROH vs. NROH Plots</a></span></li></ul></li><li><span><a href="#Suppl.-Table-4---Imputed-Age-Information" data-toc-modified-id="Suppl.-Table-4---Imputed-Age-Information-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Suppl. Table 4 - Imputed Age Information</a></span><ul class="toc-item"><li><span><a href="#Generate-COVAR-file-per-ancestry" data-toc-modified-id="Generate-COVAR-file-per-ancestry-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Generate COVAR file per ancestry</a></span></li><li><span><a href="#Extract-Age-(-Mean-±-SD)-for-Each-Ancestry" data-toc-modified-id="Extract-Age-(-Mean-±-SD)-for-Each-Ancestry-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Extract Age ( Mean ± SD) for Each Ancestry</a></span></li></ul></li><li><span><a href="#Exploration-of-Homozygosity-Parameters-(with-recessive-genes)" data-toc-modified-id="Exploration-of-Homozygosity-Parameters-(with-recessive-genes)-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Exploration of Homozygosity Parameters (with recessive genes)</a></span><ul class="toc-item"><li><span><a href="#Calculate-FROH-for-all-individuals" data-toc-modified-id="Calculate-FROH-for-all-individuals-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Calculate FROH for all individuals</a></span></li><li><span><a href="#Generate-COVAR-file-per-ancestry" data-toc-modified-id="Generate-COVAR-file-per-ancestry-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Generate COVAR file per ancestry</a></span></li><li><span><a href="#Table-1---Cases-vs.-controls" data-toc-modified-id="Table-1---Cases-vs.-controls-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Table 1 - Cases vs. controls</a></span><ul class="toc-item"><li><span><a href="#T-test:-mean-values" data-toc-modified-id="T-test:-mean-values-8.3.1"><span class="toc-item-num">8.3.1&nbsp;&nbsp;</span>T-test: mean values</a></span></li><li><span><a href="#Regression:-beta-values" data-toc-modified-id="Regression:-beta-values-8.3.2"><span class="toc-item-num">8.3.2&nbsp;&nbsp;</span>Regression: beta values</a></span></li></ul></li><li><span><a href="#Table-2---Early--and-late--onset-cases-vs.-controls" data-toc-modified-id="Table-2---Early--and-late--onset-cases-vs.-controls-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>Table 2 - Early- and late- onset cases vs. controls</a></span><ul class="toc-item"><li><span><a href="#T-test:-mean-values" data-toc-modified-id="T-test:-mean-values-8.4.1"><span class="toc-item-num">8.4.1&nbsp;&nbsp;</span>T-test: mean values</a></span></li><li><span><a href="#Regression:-beta-values" data-toc-modified-id="Regression:-beta-values-8.4.2"><span class="toc-item-num">8.4.2&nbsp;&nbsp;</span>Regression: beta values</a></span></li></ul></li><li><span><a href="#Table-3---Early--vs.-late--onset" data-toc-modified-id="Table-3---Early--vs.-late--onset-8.5"><span class="toc-item-num">8.5&nbsp;&nbsp;</span>Table 3 - Early- vs. late- onset</a></span><ul class="toc-item"><li><span><a href="#T-test:-mean-values" data-toc-modified-id="T-test:-mean-values-8.5.1"><span class="toc-item-num">8.5.1&nbsp;&nbsp;</span>T-test: mean values</a></span></li><li><span><a href="#Regression:-beta-values" data-toc-modified-id="Regression:-beta-values-8.5.2"><span class="toc-item-num">8.5.2&nbsp;&nbsp;</span>Regression: beta values</a></span></li></ul></li><li><span><a href="#Suppl.-Table-8---Linear-regression-of-ROH-and-PD-AOO" data-toc-modified-id="Suppl.-Table-8---Linear-regression-of-ROH-and-PD-AOO-8.6"><span class="toc-item-num">8.6&nbsp;&nbsp;</span>Suppl. Table 8 - Linear regression of ROH and PD AOO</a></span><ul class="toc-item"><li><span><a href="#Regression:-beta-values" data-toc-modified-id="Regression:-beta-values-8.6.1"><span class="toc-item-num">8.6.1&nbsp;&nbsp;</span>Regression: beta values</a></span></li></ul></li></ul></li><li><span><a href="#Exploration-of-Homozygosity-Parameters-(without-recessive-genes)" data-toc-modified-id="Exploration-of-Homozygosity-Parameters-(without-recessive-genes)-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Exploration of Homozygosity Parameters (without recessive genes)</a></span><ul class="toc-item"><li><span><a href="#Calculate-FROH-for-all-individuals" data-toc-modified-id="Calculate-FROH-for-all-individuals-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Calculate FROH for all individuals</a></span></li><li><span><a href="#Generate-COVAR-file-per-ancestry" data-toc-modified-id="Generate-COVAR-file-per-ancestry-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Generate COVAR file per ancestry</a></span></li><li><span><a href="#Suppl.-Table-7----Cases-vs.-controls-(excluding-recessive-genes)" data-toc-modified-id="Suppl.-Table-7----Cases-vs.-controls-(excluding-recessive-genes)-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Suppl. Table 7 -  Cases vs. controls (excluding recessive genes)</a></span><ul class="toc-item"><li><span><a href="#T-test:-mean-values" data-toc-modified-id="T-test:-mean-values-9.3.1"><span class="toc-item-num">9.3.1&nbsp;&nbsp;</span>T-test: mean values</a></span></li><li><span><a href="#Regression:-beta-values" data-toc-modified-id="Regression:-beta-values-9.3.2"><span class="toc-item-num">9.3.2&nbsp;&nbsp;</span>Regression: beta values</a></span></li></ul></li><li><span><a href="#Suppl.-Table-10---Early--and-late--onset-cases-vs.-controls-(without-recessive-genes)" data-toc-modified-id="Suppl.-Table-10---Early--and-late--onset-cases-vs.-controls-(without-recessive-genes)-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>Suppl. Table 10 - Early- and late- onset cases vs. controls (without recessive genes)</a></span><ul class="toc-item"><li><span><a href="#T-test:-mean-values" data-toc-modified-id="T-test:-mean-values-9.4.1"><span class="toc-item-num">9.4.1&nbsp;&nbsp;</span>T-test: mean values</a></span></li><li><span><a href="#Regression:-beta-values" data-toc-modified-id="Regression:-beta-values-9.4.2"><span class="toc-item-num">9.4.2&nbsp;&nbsp;</span>Regression: beta values</a></span></li></ul></li><li><span><a href="#Suppl.-Table-11----Early--vs.-late--onset-(excluding-recessive-genes)" data-toc-modified-id="Suppl.-Table-11----Early--vs.-late--onset-(excluding-recessive-genes)-9.5"><span class="toc-item-num">9.5&nbsp;&nbsp;</span>Suppl. Table 11 -  Early- vs. late- onset (excluding recessive genes)</a></span><ul class="toc-item"><li><span><a href="#T-test:-mean-values" data-toc-modified-id="T-test:-mean-values-9.5.1"><span class="toc-item-num">9.5.1&nbsp;&nbsp;</span>T-test: mean values</a></span></li><li><span><a href="#Regression:-beta-values" data-toc-modified-id="Regression:-beta-values-9.5.2"><span class="toc-item-num">9.5.2&nbsp;&nbsp;</span>Regression: beta values</a></span></li></ul></li><li><span><a href="#Suppl.-Table-9---Linear-regression-of-ROH-and-PD-AOO-(excluding-recessive-genes)" data-toc-modified-id="Suppl.-Table-9---Linear-regression-of-ROH-and-PD-AOO-(excluding-recessive-genes)-9.6"><span class="toc-item-num">9.6&nbsp;&nbsp;</span>Suppl. Table 9 - Linear regression of ROH and PD AOO (excluding recessive genes)</a></span></li></ul></li><li><span><a href="#ROH-Enrichment-in-Cases" data-toc-modified-id="ROH-Enrichment-in-Cases-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>ROH Enrichment in Cases</a></span><ul class="toc-item"><li><span><a href="#Table-4---ROH-overlapping-PD-genes" data-toc-modified-id="Table-4---ROH-overlapping-PD-genes-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Table 4 - ROH overlapping PD genes</a></span></li></ul></li><li><span><a href="#Summary-figures-for-presentations" data-toc-modified-id="Summary-figures-for-presentations-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Summary figures for presentations</a></span><ul class="toc-item"><li><span><a href="#For-homozygosity-mapping-results" data-toc-modified-id="For-homozygosity-mapping-results-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>For homozygosity mapping results</a></span><ul class="toc-item"><li><span><a href="#For-inbred-results" data-toc-modified-id="For-inbred-results-11.1.1"><span class="toc-item-num">11.1.1&nbsp;&nbsp;</span>For inbred results</a></span></li><li><span><a href="#For-EOPD-results" data-toc-modified-id="For-EOPD-results-11.1.2"><span class="toc-item-num">11.1.2&nbsp;&nbsp;</span>For EOPD results</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Getting Started

# %%
# Install necessary Python packages
# !pip install openpyxl --quiet

# Import required libraries
from pathlib import Path
import seaborn as sns
import openpyxl
import glob

# Use the os package to interact with the environment
import os

# Bring in Pandas for Dataframe functionality
import pandas as pd

# Numpy for basics
import numpy as np

# Use StringIO for working with file contents
from io import StringIO

# Enable IPython to display matplotlib graphs
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable interaction with the FireCloud API
from firecloud import api as fapi

# Import the iPython HTML rendering for displaying links to Google Cloud Console
from IPython.core.display import display, HTML

# Import urllib modules for building URLs to Google Cloud Console
import urllib.parse

# BigQuery for querying data
from google.cloud import bigquery

#Import Sys
import sys as sys
# Out:
# /tmp/ipykernel_335/298453339.py:30: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %%
# Set up R support with rpy2
# !pip install --upgrade rpy2 --quiet
# %reload_ext rpy2.ipython

# %%
# %%R
#
# # Verify that R magic is working
# print('R magic cell is working')
# Out:
# [1] "R magic cell is working"
# In addition: Warning message:
# In (function (package, help, pos = 2, lib.loc = NULL, character.only = FALSE,  :
#   libraries ‘/home/jupyter/packages’, ‘/usr/lib/R/site-library’ contain no packages

# %%
# Utility routine for printing a shell command before executing it
def shell_do(command):
    print(f'Executing: {command}', file=sys.stderr)
    # !$command
    
# Utility routine for executing a shell command and returning its output
def shell_return(command):
    print(f'Executing: {command}', file=sys.stderr)
    output = !$command
    return '\n'.join(output)

# Utility routine for executing a BigQuery query
def bq_query(query):
    print(f'Executing: {query}', file=sys.stderr)
    return pd.read_gbq(query, project_id=BILLING_PROJECT_ID, dialect='standard')

# Utility routine for displaying a message and a link
def display_html_link(description, link_text, url):
    html = f'''
    <p>
    </p>
    <p>
    {description}
    <a target=_blank href="{url}">{link_text}</a>.
    </p>
    '''
    display(HTML(html))

# Utility routines for reading files from Google Cloud Storage
def gcs_read_file(path):
    """Return the contents of a file in GCS"""
    contents = !gsutil -u {BILLING_PROJECT_ID} cat {path}
    return '\n'.join(contents)

def gcs_read_csv(path, sep=None):
    """Return a DataFrame from the contents of a delimited file in GCS"""
    return pd.read_csv(StringIO(gcs_read_file(path)), sep=sep, engine='python')

# Utility routine for displaying a message and link to Cloud Console
def link_to_cloud_console_gcs(description, link_text, gcs_path):
    url = '{}?{}'.format(
        os.path.join('https://console.cloud.google.com/storage/browser',
                     gcs_path.replace("gs://","")),
        urllib.parse.urlencode({'userProject': BILLING_PROJECT_ID}))
    display_html_link(description, link_text, url)

# %%
# %%R
#
# # Load necessary R packages
# library(data.table)
# library(magrittr)
# library(stringr)
# library(ggplot2)
# library(plyr)
# library(dplyr)
# library(tidyr)
# library(reshape2)
# library(RColorBrewer)
# Out:
# data.table 1.14.8 using 48 threads (see ?getDTthreads).  Latest news: r-datatable.com
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:plyr’:
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Attaching package: ‘tidyr’
#
# The following object is masked from ‘package:magrittr’:
#
#     extract
#
#
# Attaching package: ‘reshape2’
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths
#
# The following objects are masked from ‘package:data.table’:
#
#     dcast, melt

# %% [markdown]
# # Create Working Directory

# %%
# Make a directory for use in python
print("Making a working directory")
WORK_DIR = f'/home/jupyter/ROH_plots/'
shell_do(f'mkdir -p {WORK_DIR}')
# Out:
# Making a working directory
# Executing: mkdir -p /home/jupyter/ROH_plots/

# %%
# %%R
#
# # Set directory for use in R
# setwd(paste0("/home/jupyter/ROH_plots/") )

# %% [markdown]
# # Summary Results

# %% [markdown]
# ## Count ROH

# %%
# %%R
#
# # Define the ancestries to loop through
# ancestries <- c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Initialize an empty dataframe to store the summary statistics
# summary <- data.frame()
#
# # Loop through each ancestry to calculate the summary statistics
# for(ANC in ancestries) {
#     # Read in the ROH data for the current ancestry
#     data <- read.table(paste0(ANC, "_ROH.hom"), header = TRUE)
#
#     # Rename the 10th column to 'SNPs' for clarity
#     colnames(data)[10] <- "SNPs"
#
#     # Calculate the summary statistics and append to the summary dataframe
#     row <- data %>%
#         summarise(ANC = ANC,
#                   Total = n(),
#                   minKB = min(KB),
#                   maxKB = max(KB),
#                   meanKB = mean(KB),
#                   minSNP = min(SNPs),
#                   maxSNP = max(SNPs),
#                   meanSNP = mean(SNPs))
#
#     # Bind the result to the summary dataframe
#     summary <- rbind(summary, row)
# }
#
# # Display the summary dataframe
# summary
# Out:
#   ANC Total    minKB    maxKB   meanKB minSNP maxSNP  meanSNP
# 1 AAC  1953 1500.125 31343.16 2647.724    535  63930 5122.135
# 2 AFR  9010 1500.031 20472.12 2486.946    100  45402 4473.357
# 3  AJ 15413 1500.040 43101.72 3029.521    240  61478 4412.924
# 4 AMR  2613 1500.205 37224.84 2911.767    239  53975 4033.258
# 5 CAS  3194 1500.344 25872.98 2784.230    183  38984 3727.712
# 6 EAS 11669 1500.016 14189.65 2110.060    112  17392 2334.867
# 7 EUR 63110 1500.005 36652.78 2179.695    147  47418 2508.397
# 8 MDE  2582 1500.059 23050.92 2526.780    279  30539 3560.756
# 9 SAS  2999 1500.322 19882.37 2785.399    329  30848 3981.414

# %%
# %%R
#
# # Summarize all the ancestries by calculating overall summary statistics
# ALL <- summary %>%
#     summarise(
#         ANC = "ALL",
#         Total = sum(Total),
#         minKB = min(minKB),
#         maxKB = max(maxKB),
#         meanKB = mean(meanKB),
#         minSNP = min(minSNP),
#         maxSNP = max(maxSNP),
#         meanSNP = mean(meanSNP)
#     )
#
# # Display the combined summary for all ancestries
# ALL
# Out:
#   ANC  Total    minKB    maxKB   meanKB minSNP maxSNP meanSNP
# 1 ALL 112543 1500.005 43101.72 2606.902    100  63930 3794.98

# %%
# %%R
#
# # Combine the summary data for all ancestries with the overall summary (ALL)
# all_data <- rbind(summary, ALL)
#
# # Write the combined data to a TSV file
# fwrite(all_data, "Count_ROH.tsv", sep = "\t")

# %%
# Load the Count_ROH.tsv file with tab separation
pd.read_csv("Count_ROH.tsv", sep='\t')
# Out:
#    ANC   Total     minKB      maxKB       meanKB  minSNP  maxSNP      meanSNP
# 0  AAC    1953  1500.125  31343.156  2647.723778     535   63930  5122.134665
# 1  AFR    9010  1500.031  20472.121  2486.945765     100   45402  4473.357159
# 2   AJ   15413  1500.040  43101.725  3029.521117     240   61478  4412.923571
# 3  AMR    2613  1500.205  37224.841  2911.766812     239   53975  4033.258324
# 4  CAS    3194  1500.344  25872.984  2784.229728     183   38984  3727.711647
# 5  EAS   11669  1500.016  14189.645  2110.059979     112   17392  2334.867084
# 6  EUR   63110  1500.005  36652.775  2179.695144     147   47418  2508.397354
# 7  MDE    2582  1500.059  23050.921  2526.779552     279   30539  3560.755616
# 8  SAS    2999  1500.322  19882.366  2785.399137     329   30848  3981.413805
# 9  ALL  112543  1500.005  43101.725  2606.902335     100   63930  3794.979914

# %% [markdown]
# ## Percentage with ROH

# %%
# %%R
#
# # Define the ancestries to loop through
# ancestries <- c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Initialize an empty dataframe for summary statistics
# summary <- data.frame(NULL)
#
# # Loop through each ancestry
# for (ANC in ancestries) {
#
#   # Read in the .hom.indiv file for each ancestry
#   data <- read.table(paste0(ANC, "_ROH.hom.indiv"), header = TRUE)
#
#   # Filter out individuals with PHE value of -9 (usually missing phenotype)
#   data <- data[data$PHE != -9, ]
#
#   # Create a new column: 1 if the individual harbours ROH (NSEG > 0), else 0
#   data$harbourROH <- ifelse(data$NSEG == 0, 0, 1)
#
#   # Summarise the data by PHE (cases/controls), counting individuals who harbour ROH
#   row <- data %>%
#     group_by(PHE) %>%
#     summarise(
#       ANC = ANC,  # Include the ancestry
#       Total = n(),  # Total number of individuals
#       harbourROH = sum(harbourROH),  # Count of individuals with ROH
#       Percentage = harbourROH / Total  # Percentage of individuals with ROH
#     )
#
#   # Append the summarised row to the summary dataframe
#   summary <- rbind(summary, row)
# }
#
# # Display the final summary
# summary
# Out:
# # A tibble: 18 × 5
#      PHE ANC   Total harbourROH Percentage
#    <int> <chr> <int>      <dbl>      <dbl>
#  1     1 AAC     804        591      0.735
#  2     2 AAC     256        200      0.781
#  3     1 AFR    1631       1461      0.896
#  4     2 AFR     917        867      0.945
#  5     1 AJ      458        454      0.991
#  6     2 AJ     1001        995      0.994
#  7     1 AMR     139        134      0.964
#  8     2 AMR     363        343      0.945
#  9     1 CAS     267        248      0.929
# 10     2 CAS     265        235      0.887
# 11     1 EAS    2302       2091      0.908
# 12     2 EAS    1537       1336      0.869
# 13     1 EUR    7505       7028      0.936
# 14     2 EUR   11679      10925      0.935
# 15     1 MDE      20         17      0.85
# 16     2 MDE     214        199      0.930
# 17     1 SAS     198        181      0.914
# 18     2 SAS     117        110      0.940

# %%
# %%R
#
# # Pivot the summary dataframe to a wide format, separating controls and cases
# data_wide <- summary %>%
#   pivot_wider(names_from = PHE, values_from = c(Total, harbourROH, Percentage), names_prefix = "PHE") %>%
#   rename(
#     Controls = Total_PHE1,             # Rename Total_PHE1 to Controls
#     Cases = Total_PHE2,                # Rename Total_PHE2 to Cases
#     Controls.ROH = harbourROH_PHE1,    # Rename harbourROH_PHE1 to Controls.ROH
#     Cases.ROH = harbourROH_PHE2,       # Rename harbourROH_PHE2 to Cases.ROH
#     Controls.Percentage = Percentage_PHE1,  # Rename Percentage_PHE1 to Controls.Percentage
#     Cases.Percentage = Percentage_PHE2      # Rename Percentage_PHE2 to Cases.Percentage
#   )
# data_wide
#
# # Summarise totals across all ancestries (ALL row)
# all_row <- data.frame(
#   ANC = "ALL",  # All ancestries combined
#   Controls = as.numeric(sum(data_wide$Controls)),       # Total controls
#   Cases = as.numeric(sum(data_wide$Cases)),             # Total cases
#   Controls.ROH = sum(data_wide$Controls.ROH),           # Total controls with ROH
#   Cases.ROH = sum(data_wide$Cases.ROH)                  # Total cases with ROH
# )
#
# # Calculate percentages for the combined row
# all_row$Controls.Percentage <- all_row$Controls.ROH / all_row$Controls
# all_row$Cases.Percentage <- all_row$Cases.ROH / all_row$Cases
#
# # Combine the ALL row with the rest of the data
# all_data <- rbind(data_wide, all_row)
#
# # Calculate the ratio of Cases to Controls percentages
# all_data$ratio <- all_data$Cases.Percentage / all_data$Controls.Percentage
#
# # Initialize a dataframe for storing p-values
# pvalue_column <- data.frame(NULL)
#
# # List of ancestries including the combined "ALL" group
# ancestries <- c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS", "ALL")
#
# # Perform a proportion test for each ancestry
# for (ANC in 1:length(ancestries)) {
#   cases_ROH <- all_data$Cases.ROH[ANC]
#   control_ROH <- all_data$Controls.ROH[ANC]
#   cases <- all_data$Cases[ANC]
#   controls <- all_data$Controls[ANC]
#
#   # Proportion test to check the significance of ROH differences between cases and controls
#   pvalue <- prop.test(x = c(cases_ROH, control_ROH), n = c(cases, controls))$p.value
#   pvalue_column <- rbind(pvalue_column, pvalue)  # Append p-values to the dataframe
# }
#
# # Add the p-values to the final all_data dataframe
# all_data <- cbind(all_data, pvalue_column)
# colnames(all_data)[9] <- "pvalue"  # Rename the new column to 'pvalue'
#
# # Save the results to a file
# fwrite(all_data, "percentage_ROH.tsv", sep = '\t')
# Out:
# In addition: Warning messages:
# 1: In prop.test(x = c(cases_ROH, control_ROH), n = c(cases, controls)) :
#   Chi-squared approximation may be incorrect
# 2: In prop.test(x = c(cases_ROH, control_ROH), n = c(cases, controls)) :
#   Chi-squared approximation may be incorrect

# %%
# Read the tab-separated file
pd.read_csv("percentage_ROH.tsv", sep='\t')
# Out:
#    ANC  Controls  Cases  Controls.ROH  Cases.ROH  Controls.Percentage  \
# 0  AAC       804    256           591        200             0.735075
# 1  AFR      1631    917          1461        867             0.895769
# 2   AJ       458   1001           454        995             0.991266
# 3  AMR       139    363           134        343             0.964029
# 4  CAS       267    265           248        235             0.928839
# 5  EAS      2302   1537          2091       1336             0.908341
# 6  EUR      7505  11679          7028      10925             0.936442
# 7  MDE        20    214            17        199             0.850000
# 8  SAS       198    117           181        110             0.914141
# 9  ALL     13324  16349         12205      15210             0.916016
#
#    Cases.Percentage     ratio    pvalue
# 0          0.781250  1.062817  0.162675
# 1          0.945474  1.055489  0.000025
# 2          0.994006  1.002764  0.805108
# ...

# %% [markdown]
# ## FROH in all ancestries

# %%
# %%R
#
# # Define the ancestries to loop through
# ancestries <- c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Initialize an empty data frame to store FROH results for all ancestries
# data_all <- data.frame(NULL)
#
# # Loop through each ancestry to calculate FROH
# for (ANC in 1:length(ancestries)) {
#
#   # Read the ROH data (.hom.indiv file) for the current ancestry
#   data <- read.table(paste0(ancestries[ANC], "_ROH.hom.indiv"), header = TRUE)
#
#   # Calculate FROH by dividing the total ROH length (KB) by the total autosomal genome length (2,886,428 Kb)
#   data$FROH <- round(data$KB / 2886428, digits = 5)  # 5 digits precision
#
#   # Summarize the mean FROH value for the current ancestry
#   row <- data %>%
#     summarise(ANC = ancestries[ANC], FROH = mean(FROH))  # Calculate mean FROH
#
#   # Append the result to the data_all data frame
#   data_all <- rbind(data_all, row)
# }
#
# # Write the final FROH data to a .tsv file
# fwrite(data_all, "FROH_in_all_ancestries.tsv", sep = '\t')

# %%
# Load the FROH data
pd.read_csv("FROH_in_all_ancestries.tsv", sep='\t')
# Out:
#    ANC      FROH
# 0  AAC  0.001677
# 1  AFR  0.003031
# 2   AJ  0.007599
# 3  AMR  0.005030
# 4  CAS  0.005748
# 5  EAS  0.002201
# 6  EUR  0.002312
# 7  MDE  0.008795
# 8  SAS  0.008877

# %% [markdown]
# ## Figure 3

# %% [markdown]
# ### Mean values

# %%
# %%R
#
# # Define the ancestries to loop through
# ancestries <- c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Initialize an empty data frame to store the summaries
# data_all <- data.frame(NULL)
#
# # Loop through each ancestry and calculate the mean ROH segments (NROH) and size (SROH)
# for (ANC in 1:length(ancestries)) {
#     # Read the ROH data for the current ancestry
#     data <- read.table(paste0(ancestries[ANC], "_ROH.hom.indiv"), header = TRUE)
#
#     # Summarize the data: mean number of ROH segments (NROH) and mean size of ROH in Kb (SROH)
#     data_summary <- data %>%
#         summarise(ANC = ancestries[ANC],
#                   NROH = mean(NSEG),    # Average number of ROH segments
#                   SROH = mean(KB) / 1000)  # Convert ROH size from Kb to Mb
#
#     # Append the summary to the final data frame
#     data_all <- rbind(data_all, data_summary)
# }
#
# # Display the summarized data
# data_all
# Out:
#   ANC      NROH      SROH
# 1 AAC  1.828652  4.841766
# 2 AFR  3.518157  8.749466
# 3  AJ  7.239549 21.932368
# 4 AMR  4.986641 14.519936
# 5 CAS  5.958955 16.591101
# 6 EAS  3.010578  6.352500
# 7 EUR  3.061660  6.673486
# 8 MDE 10.046693 25.385783
# 9 SAS  9.199387 25.623967

# %%
# %%R
#
# # Define the ancestries to loop through
# ancestries <- c("AAC", "AFR", "AJ" ,"AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Initialize an empty data frame to store the summaries
# data_all <- data.frame(NULL)
#
# # Loop through each ancestry and calculate the mean and standard deviation for ROH segments (NROH) and size (SROH)
# for(ANC in 1:length(ancestries)) {
#     # Read the ROH data for the current ancestry
#     data <- read.table(paste0(ancestries[ANC], "_ROH.hom.indiv"), header = TRUE)
#
#     # Summarize data: mean and standard deviation of NROH and SROH
#     data_summary <- data %>%
#         summarise(ANC = ancestries[ANC],
#                   NROH_mean = mean(NSEG),       # Mean number of ROH segments
#                   NROH_sd = sd(NSEG),           # Standard deviation of NROH
#                   SROH_mean = mean(KB) / 1000,  # Mean ROH size in Mb
#                   SROH_sd = sd(KB) / 1000)      # Standard deviation of ROH size in Mb
#
#     # Append summary to the final data frame
#     data_all <- rbind(data_all, data_summary)
# }
#
# # Calculate overall mean and standard deviation for all ancestries combined
# overall_summary <- data_all %>%
#     summarise(Overall_NROH_mean = mean(NROH_mean),
#               Overall_NROH_sd = sd(NROH_mean),
#               Overall_SROH_mean = mean(SROH_mean),
#               Overall_SROH_sd = sd(SROH_mean))
#
# # Print results
# print(data_all)        # Print summary by ancestry
# print(overall_summary) # Print overall summary
# Out:
#   ANC NROH_mean   NROH_sd SROH_mean   SROH_sd
# 1 AAC  1.828652  3.007900  4.841766 12.144496
# 2 AFR  3.518157  4.006021  8.749466 12.694729
# 3  AJ  7.239549  4.380827 21.932368 23.264073
# 4 AMR  4.986641  5.213401 14.519936 25.292654
# 5 CAS  5.958955 10.610795 16.591101 37.654825
# 6 EAS  3.010578  3.668332  6.352500  8.887330
# 7 EUR  3.061660  2.895544  6.673486  9.405489
# 8 MDE 10.046693 14.035869 25.385783 39.817955
# 9 SAS  9.199387 15.012204 25.623967 48.144993
#   Overall_NROH_mean Overall_NROH_sd Overall_SROH_mean Overall_SROH_sd
# 1          5.427808        2.901732          14.51893        8.335459

# %%
# %%R
#
# # Plot size of ROH segments (SROH) > 1.5 Mb against the mean number of ROH segments (NROH)
# ggplot(data_all, aes(x = SROH_mean, y = NROH_mean, colour = ANC)) +
#     geom_point(size = 3) +                        # Use larger points
#     theme_minimal() +                             # Minimal theme for clean aesthetics
#     xlim(0, 40) +                                 # Limit x-axis from 0 to 40 Mb
#     ylim(0, 15) +                                 # Limit y-axis from 0 to 15 segments
#     labs(colour = "Ancestry",                     # Label for the legend (colour by ancestry)
#          x = "SROH (in Mb)",                     # X-axis label for size of ROH segments (> 1.5 Mb)
#          y = "Mean NROH") +                       # Y-axis label for number of ROH segments
#     scale_colour_brewer(palette = "Set1")         # Use the "Set1" colour palette for distinct colours

# %%
# %%R
#
# # Save the last plot as a JPEG file
# ggsave("Summary_plot_cohort1.jpeg", width = 8, height = 6, dpi = 300)

# %% [markdown]
# ### Individual values

# %%
# %%R
#
# # Define the ancestries to loop through
# ancestries <- c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Initialize an empty data frame to store all the results
# data_all <- data.frame(NULL)
#
# # Loop through each ancestry to process the ROH data
# for (ANC in ancestries) {
#
#   # Read the ROH file for the current ancestry
#   data <- read.table(paste0(ANC, "_ROH.hom.indiv"), header = TRUE)
#
#   # Select the columns of interest: Individual ID, Number of Segments (NSEG), and Length in KB (KB)
#   data_summary <- data[c("IID", "NSEG", "KB")]
#
#   # Convert KB (length in kilobases) to megabases (MB)
#   data_summary$KB <- data_summary$KB / 1000
#
#   # Rename the columns for clarity
#   colnames(data_summary) <- c("ID", "NROH", "SROH")  # NROH = Number of ROH, SROH = Size of ROH in MB
#
#   # Add a column for the ancestry information
#   data_summary$ANC <- ANC
#
#   # Append the current ancestry's data to the overall data frame
#   data_all <- rbind(data_all, data_summary)
# }

# %%
# %%R
#
# # Plot size of ROH segments (SROH) > 1.5 Mb against the mean number of ROH segments (NROH)
# ggplot(data_all, aes(x = SROH, y = NROH, colour = ANC)) +
#   geom_jitter(width = 0.2, height = 0.2) +  # Adds jitter to avoid overplotting
#   theme_minimal() +
#   labs(colour = "Ancestry", # Label for the legend (colour by ancestry)
#        x = "SROH (in Mb)",  # X-axis label for size of ROH segments > 1.5 Mb
#        y = "Mean NROH") +  # X-axis label for number of ROH segments
#   scale_colour_brewer(palette = "Set1") +  # Use the "Set1" colour palette for distinct colours
#   theme(legend.position = "right")  # Move legend to the right for better visibility

# %%
# %%R
#
# # Save the last plot as a JPEG file
# ggsave("Summary_plot_Individuals.jpeg", width = 8, height = 6, dpi = 300)

# %% [markdown]
# # Inbreeding Coefficient Plots

# %% [markdown]
# ## Plot

# %%
# %%R
#
# # Function to load inbreeding and phenotype data, merge, and assign ancestry
# load_and_merge_data <- function(ancestry) {
#   inbreeding_data <- fread(paste0(ancestry, "_inbreeding.het"))[, .(IID, F)]  # Load inbreeding data (IID, F)
#   phenotype_data <- fread(paste0(ancestry, "_release6.psam"))[, .(`#IID`, PHENO1)]  # Load phenotype data
#   setnames(phenotype_data, old = "#IID", new = "IID")  # Rename column to match inbreeding data
#   setnames(phenotype_data, old = "PHENO1", new = "PHENO")
#
#   # Merge inbreeding data and phenotype data
#   merged_data <- merge(inbreeding_data, phenotype_data, by = "IID")
#
#   # Add ancestry column
#   merged_data[, Ancestry := ancestry]
#
#   return(merged_data)
# }
#
# # List of ancestries
# ancestries <- c("AJ", "AAC", "AFR", "AMR", "CAS", "EAS", "MDE", "SAS", "EUR")
#
# # Apply the function to each ancestry and store the result in a list
# ancestry_data_list <- lapply(ancestries, load_and_merge_data)
#
# # Combine all ancestry data into one data.table
# combined_data <- rbindlist(ancestry_data_list)

# %% [markdown]
# ### Figure 4A - All Individuals

# %%
# %%R
#
# # Plot the density of inbreeding coefficient (F) across ancestries for all individuals
# ggplot(combined_data, aes(F, colour = Ancestry, fill = Ancestry)) +
#     geom_density(alpha = 0.5) +       # Semi-transparent density plots
#     xlim(-0.07, 0.15) +               # Set x-axis limits for F values
#     theme_bw() +                      # Apply a clean theme
#     labs(
#         title = "Inbreeding Coefficients by Ancestry",  # Title for clarity
#         x = "F (Inbreeding Coefficient)",               # X-axis label
#         y = "Density"                                   # Y-axis label
#     )
# Out:
# R[write to console]: In addition:
# R[write to console]: Warning message:
#
# R[write to console]: Removed 11 rows containing non-finite values (`stat_density()`).

# %%
# %%R
#
# # Save the last plot as a JPEG file
# ggsave("All_ancestries_het.jpeg", width = 8, height = 6, dpi = 300)
# Out:
# In addition: Warning message:
# Removed 11 rows containing non-finite values (`stat_density()`).

# %% [markdown]
# ### Figure 4B - Only Cases

# %%
# %%R
#
# # Filter to include only cases where PHENO == 2 (typically cases in a case-control study)
# all_filtered <- combined_data[combined_data$PHENO == 2, ]
#
# # Plot the density of inbreeding coefficient (F) across ancestries for cases
# ggplot(all_filtered, aes(F, fill = Ancestry, colour = Ancestry)) +
#     geom_density(alpha = 0.5) +         # Semi-transparent density plots
#     xlim(-0.07, 0.15) +                 # Set x-axis limits for F values
#     theme_bw() +                        # Apply a clean theme
#     labs(
#         title = "Inbreeding Coefficients by Ancestry (Cases)",  # Add a title
#         x = "F (Inbreeding Coefficient)",                      # X-axis label
#         y = "Density"                                           # Y-axis label
#     )
# Out:
# R[write to console]: In addition:
# R[write to console]: Warning message:
#
# R[write to console]: Removed 6 rows containing non-finite values (`stat_density()`).

# %%
# %%R
#
# # Save the last plot as a JPEG file
# ggsave("All_ancestries_cases_het.jpeg", width = 8, height = 6, dpi = 300)
# Out:
# In addition: Warning message:
# Removed 6 rows containing non-finite values (`stat_density()`).

# %% [markdown]
# ### Figure 4C - Only Controls

# %%
# %%R
#
# # Filter to include only controls where PHENO == 1 (typically controls in a case-control study)
# all_filtered <- combined_data[combined_data$PHENO == 1, ]
#
# # Plot the density of inbreeding coefficient (F) across ancestries for controls
# ggplot(all_filtered, aes(F, fill = Ancestry, colour = Ancestry)) +
#     geom_density(alpha = 0.5) +         # Semi-transparent density plots
#     xlim(-0.07, 0.15) +                 # Set x-axis limits for F values
#     theme_bw() +                        # Apply a clean theme
#     labs(
#         title = "Inbreeding Coefficients by Ancestry (Controls)",  # Add a title
#         x = "F (Inbreeding Coefficient)",                      # X-axis label
#         y = "Density"                                           # Y-axis label
#     )
# Out:
# R[write to console]: In addition:
# R[write to console]: Warning message:
#
# R[write to console]: Removed 4 rows containing non-finite values (`stat_density()`).

# %%
# %%R
#
# # Save the last plot as a JPEG file
# ggsave("All_ancestries_controls_het.jpeg", width = 8, height = 6, dpi = 300)
# Out:
# In addition: Warning message:
# Removed 4 rows containing non-finite values (`stat_density()`).

# %% [markdown]
# # Suppl. Figure 1 - Scree Plots

# %%
# %%R
#
# # AAC Scree Plot
#
# ANC <- "AAC"
#
# # Load the PCA eigenvalues for AAC ancestry
# eigenval <- read.delim(paste0(ANC, "_release6.eigenval"), sep = "\t", header = FALSE, stringsAsFactors = FALSE)
#
# # Rename the first column to "Eigenvalues" and create a PC column
# colnames(eigenval)[1] <- "Eigenvalues"
# eigenval$PC <- 1:nrow(eigenval)  # Create a PC column
#
# # Calculate the percentage of variance explained by each PC
# eigenval$VarianceExplained <- eigenval$Eigenvalues / sum(eigenval$Eigenvalues) * 100
#
# # Keep only the first 10 principal components
# eigenval2 <- head(eigenval, 10)
#
# # Create the scree plot
# scree_ANC <- ggplot(data = eigenval2, aes(x = PC, y = VarianceExplained)) +
#   geom_line() +                   # Add a line between the points
#   geom_point() +                  # Plot points for each PC
#   theme_bw() +                    # Apply a clean white-black theme
#   theme(panel.grid.minor = element_blank()) +  # Remove minor gridlines
#   scale_x_continuous(name = "Principal Components", breaks = seq(1, 10, 1), limits = c(1, 10)) +
#   scale_y_continuous(name = "Percent (%) Variance Explained", breaks = seq(0, 50, 5), limits = c(0, 50)) +
#   ggtitle(paste("Scree Plot:", ANC, "Ancestry")) +  # Title of the plot with ancestry name
#   theme(plot.title = element_text(hjust = 0.5, face = "bold"))  # Center and bold the title
#
# # Print the scree plot for AAC ancestry
# print(scree_ANC)
#
# # Save the scree plot as PDF and JPEG
# ggsave(paste0("ScreePlot_", ANC, ".pdf"), plot = scree_ANC, width = 5, height = 3.5, units = "in")
# ggsave(paste0("ScreePlot_", ANC, ".jpeg"), plot = scree_ANC, width = 8, height = 6, dpi = 300)

# %%
# %%R
#
# # AFR Scree Plot
#
# ANC <- "AFR"
#
# # Load the PCA eigenvalues for AFR ancestry
# eigenval <- read.delim(paste0(ANC, "_release6.eigenval"), sep = "\t", header = FALSE, stringsAsFactors = FALSE)
#
# # Rename the first column to "Eigenvalues" and create a PC column
# colnames(eigenval)[1] <- "Eigenvalues"
# eigenval$PC <- 1:nrow(eigenval)  # Create a PC column
#
# # Calculate the percentage of variance explained by each PC
# eigenval$VarianceExplained <- eigenval$Eigenvalues / sum(eigenval$Eigenvalues) * 100
#
# # Keep only the first 10 principal components
# eigenval2 <- head(eigenval, 10)
#
# # Create the scree plot
# scree_ANC <- ggplot(data = eigenval2, aes(x = PC, y = VarianceExplained)) +
#   geom_line() +                   # Add a line between the points
#   geom_point() +                  # Plot points for each PC
#   theme_bw() +                    # Apply a clean white-black theme
#   theme(panel.grid.minor = element_blank()) +  # Remove minor gridlines
#   scale_x_continuous(name = "Principal Components", breaks = seq(1, 10, 1), limits = c(1, 10)) +
#   scale_y_continuous(name = "Percent (%) Variance Explained", breaks = seq(0, 50, 5), limits = c(0, 50)) +
#   ggtitle(paste("Scree Plot:", ANC, "Ancestry")) +  # Title of the plot with ancestry name
#   theme(plot.title = element_text(hjust = 0.5, face = "bold"))  # Center and bold the title
#
# # Print the scree plot for AFR ancestry
# print(scree_ANC)
#
# # Save the scree plot as PDF and JPEG
# ggsave(paste0("ScreePlot_", ANC, ".pdf"), plot = scree_ANC, width = 5, height = 3.5, units = "in")
# ggsave(paste0("ScreePlot_", ANC, ".jpeg"), plot = scree_ANC, width = 8, height = 6, dpi = 300)

# %%
# %%R
#
# # AJ Scree Plot
#
# ANC <- "AJ"
#
# # Load the PCA eigenvalues for AJ ancestry
# eigenval <- read.delim(paste0(ANC, "_release6.eigenval"), sep = "\t", header = FALSE, stringsAsFactors = FALSE)
#
# # Rename the first column to "Eigenvalues" and create a PC column
# colnames(eigenval)[1] <- "Eigenvalues"
# eigenval$PC <- 1:nrow(eigenval)  # Create a PC column
#
# # Calculate the percentage of variance explained by each PC
# eigenval$VarianceExplained <- eigenval$Eigenvalues / sum(eigenval$Eigenvalues) * 100
#
# # Keep only the first 10 principal components
# eigenval2 <- head(eigenval, 10)
#
# # Create the scree plot
# scree_ANC <- ggplot(data = eigenval2, aes(x = PC, y = VarianceExplained)) +
#   geom_line() +                   # Add a line between the points
#   geom_point() +                  # Plot points for each PC
#   theme_bw() +                    # Apply a clean white-black theme
#   theme(panel.grid.minor = element_blank()) +  # Remove minor gridlines
#   scale_x_continuous(name = "Principal Components", breaks = seq(1, 10, 1), limits = c(1, 10)) +
#   scale_y_continuous(name = "Percent (%) Variance Explained", breaks = seq(0, 50, 5), limits = c(0, 50)) +
#   ggtitle(paste("Scree Plot:", ANC, "Ancestry")) +  # Title of the plot with ancestry name
#   theme(plot.title = element_text(hjust = 0.5, face = "bold"))  # Center and bold the title
#
# # Print the scree plot for AJ ancestry
# print(scree_ANC)
#
# # Save the scree plot as PDF and JPEG
# ggsave(paste0("ScreePlot_", ANC, ".pdf"), plot = scree_ANC, width = 5, height = 3.5, units = "in")
# ggsave(paste0("ScreePlot_", ANC, ".jpeg"), plot = scree_ANC, width = 8, height = 6, dpi = 300)

# %%
# %%R
#
# # AMR Scree Plot
#
# ANC <- "AMR"
#
# # Load the PCA eigenvalues for AMR ancestry
# eigenval <- read.delim(paste0(ANC, "_release6.eigenval"), sep = "\t", header = FALSE, stringsAsFactors = FALSE)
#
# # Rename the first column to "Eigenvalues" and create a PC column
# colnames(eigenval)[1] <- "Eigenvalues"
# eigenval$PC <- 1:nrow(eigenval)  # Create a PC column
#
# # Calculate the percentage of variance explained by each PC
# eigenval$VarianceExplained <- eigenval$Eigenvalues / sum(eigenval$Eigenvalues) * 100
#
# # Keep only the first 10 principal components
# eigenval2 <- head(eigenval, 10)
#
# # Create the scree plot
# scree_ANC <- ggplot(data = eigenval2, aes(x = PC, y = VarianceExplained)) +
#   geom_line() +                   # Add a line between the points
#   geom_point() +                  # Plot points for each PC
#   theme_bw() +                    # Apply a clean white-black theme
#   theme(panel.grid.minor = element_blank()) +  # Remove minor gridlines
#   scale_x_continuous(name = "Principal Components", breaks = seq(1, 10, 1), limits = c(1, 10)) +
#   scale_y_continuous(name = "Percent (%) Variance Explained", breaks = seq(0, 50, 5), limits = c(0, 50)) +
#   ggtitle(paste("Scree Plot:", ANC, "Ancestry")) +  # Title of the plot with ancestry name
#   theme(plot.title = element_text(hjust = 0.5, face = "bold"))  # Center and bold the title
#
# # Print the scree plot for AMR ancestry
# print(scree_ANC)
#
# # Save the scree plot as PDF and JPEG
# ggsave(paste0("ScreePlot_", ANC, ".pdf"), plot = scree_ANC, width = 5, height = 3.5, units = "in")
# ggsave(paste0("ScreePlot_", ANC, ".jpeg"), plot = scree_ANC, width = 8, height = 6, dpi = 300)

# %%
# %%R
#
# # CAS Scree Plot
#
# ANC <- "CAS"
#
# # Load the PCA eigenvalues for CAS ancestry
# eigenval <- read.delim(paste0(ANC, "_release6.eigenval"), sep = "\t", header = FALSE, stringsAsFactors = FALSE)
#
# # Rename the first column to "Eigenvalues" and create a PC column
# colnames(eigenval)[1] <- "Eigenvalues"
# eigenval$PC <- 1:nrow(eigenval)  # Create a PC column
#
# # Calculate the percentage of variance explained by each PC
# eigenval$VarianceExplained <- eigenval$Eigenvalues / sum(eigenval$Eigenvalues) * 100
#
# # Keep only the first 10 principal components
# eigenval2 <- head(eigenval, 10)
#
# # Create the scree plot
# scree_ANC <- ggplot(data = eigenval2, aes(x = PC, y = VarianceExplained)) +
#   geom_line() +                   # Add a line between the points
#   geom_point() +                  # Plot points for each PC
#   theme_bw() +                    # Apply a clean white-black theme
#   theme(panel.grid.minor = element_blank()) +  # Remove minor gridlines
#   scale_x_continuous(name = "Principal Components", breaks = seq(1, 10, 1), limits = c(1, 10)) +
#   scale_y_continuous(name = "Percent (%) Variance Explained", breaks = seq(0, 50, 5), limits = c(0, 50)) +
#   ggtitle(paste("Scree Plot:", ANC, "Ancestry")) +  # Title of the plot with ancestry name
#   theme(plot.title = element_text(hjust = 0.5, face = "bold"))  # Center and bold the title
#
# # Print the scree plot for CAS ancestry
# print(scree_ANC)
#
# # Save the scree plot as PDF and JPEG
# ggsave(paste0("ScreePlot_", ANC, ".pdf"), plot = scree_ANC, width = 5, height = 3.5, units = "in")
# ggsave(paste0("ScreePlot_", ANC, ".jpeg"), plot = scree_ANC, width = 8, height = 6, dpi = 300)

# %%
# %%R
#
# # EAS Scree Plot
#
# ANC <- "EAS"
#
# # Load the PCA eigenvalues for EAS ancestry
# eigenval <- read.delim(paste0(ANC, "_release6.eigenval"), sep = "\t", header = FALSE, stringsAsFactors = FALSE)
#
# # Rename the first column to "Eigenvalues" and create a PC column
# colnames(eigenval)[1] <- "Eigenvalues"
# eigenval$PC <- 1:nrow(eigenval)  # Create a PC column
#
# # Calculate the percentage of variance explained by each PC
# eigenval$VarianceExplained <- eigenval$Eigenvalues / sum(eigenval$Eigenvalues) * 100
#
# # Keep only the first 10 principal components
# eigenval2 <- head(eigenval, 10)
#
# # Create the scree plot
# scree_ANC <- ggplot(data = eigenval2, aes(x = PC, y = VarianceExplained)) +
#   geom_line() +                   # Add a line between the points
#   geom_point() +                  # Plot points for each PC
#   theme_bw() +                    # Apply a clean white-black theme
#   theme(panel.grid.minor = element_blank()) +  # Remove minor gridlines
#   scale_x_continuous(name = "Principal Components", breaks = seq(1, 10, 1), limits = c(1, 10)) +
#   scale_y_continuous(name = "Percent (%) Variance Explained", breaks = seq(0, 50, 5), limits = c(0, 50)) +
#   ggtitle(paste("Scree Plot:", ANC, "Ancestry")) +  # Title of the plot with ancestry name
#   theme(plot.title = element_text(hjust = 0.5, face = "bold"))  # Center and bold the title
#
# # Print the scree plot for EAS ancestry
# print(scree_ANC)
#
# # Save the scree plot as PDF and JPEG
# ggsave(paste0("ScreePlot_", ANC, ".pdf"), plot = scree_ANC, width = 5, height = 3.5, units = "in")
# ggsave(paste0("ScreePlot_", ANC, ".jpeg"), plot = scree_ANC, width = 8, height = 6, dpi = 300)

# %%
# %%R
#
# # EUR Scree Plot
#
# ANC <- "EUR"
#
# # Load the PCA eigenvalues for EUR ancestry
# eigenval <- read.delim(paste0(ANC, "_release6.eigenval"), sep = "\t", header = FALSE, stringsAsFactors = FALSE)
#
# # Rename the first column to "Eigenvalues" and create a PC column
# colnames(eigenval)[1] <- "Eigenvalues"
# eigenval$PC <- 1:nrow(eigenval)  # Create a PC column
#
# # Calculate the percentage of variance explained by each PC
# eigenval$VarianceExplained <- eigenval$Eigenvalues / sum(eigenval$Eigenvalues) * 100
#
# # Keep only the first 10 principal components
# eigenval2 <- head(eigenval, 10)
#
# # Create the scree plot
# scree_ANC <- ggplot(data = eigenval2, aes(x = PC, y = VarianceExplained)) +
#   geom_line() +                   # Add a line between the points
#   geom_point() +                  # Plot points for each PC
#   theme_bw() +                    # Apply a clean white-black theme
#   theme(panel.grid.minor = element_blank()) +  # Remove minor gridlines
#   scale_x_continuous(name = "Principal Components", breaks = seq(1, 10, 1), limits = c(1, 10)) +
#   scale_y_continuous(name = "Percent (%) Variance Explained", breaks = seq(0, 50, 5), limits = c(0, 50)) +
#   ggtitle(paste("Scree Plot:", ANC, "Ancestry")) +  # Title of the plot with ancestry name
#   theme(plot.title = element_text(hjust = 0.5, face = "bold"))  # Center and bold the title
#
# # Print the scree plot for EUR ancestry
# print(scree_ANC)
#
# # Save the scree plot as PDF and JPEG
# ggsave(paste0("ScreePlot_", ANC, ".pdf"), plot = scree_ANC, width = 5, height = 3.5, units = "in")
# ggsave(paste0("ScreePlot_", ANC, ".jpeg"), plot = scree_ANC, width = 8, height = 6, dpi = 300)

# %%
# %%R
#
# # MDE Scree Plot
#
# ANC <- "MDE"
#
# # Load the PCA eigenvalues for MDE ancestry
# eigenval <- read.delim(paste0(ANC, "_release6.eigenval"), sep = "\t", header = FALSE, stringsAsFactors = FALSE)
#
# # Rename the first column to "Eigenvalues" and create a PC column
# colnames(eigenval)[1] <- "Eigenvalues"
# eigenval$PC <- 1:nrow(eigenval)  # Create a PC column
#
# # Calculate the percentage of variance explained by each PC
# eigenval$VarianceExplained <- eigenval$Eigenvalues / sum(eigenval$Eigenvalues) * 100
#
# # Keep only the first 10 principal components
# eigenval2 <- head(eigenval, 10)
#
# # Create the scree plot
# scree_ANC <- ggplot(data = eigenval2, aes(x = PC, y = VarianceExplained)) +
#   geom_line() +                   # Add a line between the points
#   geom_point() +                  # Plot points for each PC
#   theme_bw() +                    # Apply a clean white-black theme
#   theme(panel.grid.minor = element_blank()) +  # Remove minor gridlines
#   scale_x_continuous(name = "Principal Components", breaks = seq(1, 10, 1), limits = c(1, 10)) +
#   scale_y_continuous(name = "Percent (%) Variance Explained", breaks = seq(0, 50, 5), limits = c(0, 50)) +
#   ggtitle(paste("Scree Plot:", ANC, "Ancestry")) +  # Title of the plot with ancestry name
#   theme(plot.title = element_text(hjust = 0.5, face = "bold"))  # Center and bold the title
#
# # Print the scree plot for MDE ancestry
# print(scree_ANC)
#
# # Save the scree plot as PDF and JPEG
# ggsave(paste0("ScreePlot_", ANC, ".pdf"), plot = scree_ANC, width = 5, height = 3.5, units = "in")
# ggsave(paste0("ScreePlot_", ANC, ".jpeg"), plot = scree_ANC, width = 8, height = 6, dpi = 300)

# %%
# %%R
#
# # SAS Scree Plot
#
# ANC <- "SAS"
#
# # Load the PCA eigenvalues for SAS ancestry
# eigenval <- read.delim(paste0(ANC, "_release6.eigenval"), sep = "\t", header = FALSE, stringsAsFactors = FALSE)
#
# # Rename the first column to "Eigenvalues" and create a PC column
# colnames(eigenval)[1] <- "Eigenvalues"
# eigenval$PC <- 1:nrow(eigenval)  # Create a PC column
#
# # Calculate the percentage of variance explained by each PC
# eigenval$VarianceExplained <- eigenval$Eigenvalues / sum(eigenval$Eigenvalues) * 100
#
# # Keep only the first 10 principal components
# eigenval2 <- head(eigenval, 10)
#
# # Create the scree plot
# scree_ANC <- ggplot(data = eigenval2, aes(x = PC, y = VarianceExplained)) +
#   geom_line() +                   # Add a line between the points
#   geom_point() +                  # Plot points for each PC
#   theme_bw() +                    # Apply a clean white-black theme
#   theme(panel.grid.minor = element_blank()) +  # Remove minor gridlines
#   scale_x_continuous(name = "Principal Components", breaks = seq(1, 10, 1), limits = c(1, 10)) +
#   scale_y_continuous(name = "Percent (%) Variance Explained", breaks = seq(0, 50, 5), limits = c(0, 50)) +
#   ggtitle(paste("Scree Plot:", ANC, "Ancestry")) +  # Title of the plot with ancestry name
#   theme(plot.title = element_text(hjust = 0.5, face = "bold"))  # Center and bold the title
#
# # Print the scree plot for SAS ancestry
# print(scree_ANC)
#
# # Save the scree plot as PDF and JPEG
# ggsave(paste0("ScreePlot_", ANC, ".pdf"), plot = scree_ANC, width = 5, height = 3.5, units = "in")
# ggsave(paste0("ScreePlot_", ANC, ".jpeg"), plot = scree_ANC, width = 8, height = 6, dpi = 300)

# %% [markdown]
# # ROH Parameters Plots

# %% [markdown]
# ## Find better range of data

# %%
# %%R
#
# # Loop over each ancestry and read the individual-level ROH data
# for (ANC in c('AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'MDE', 'SAS')) {
#
#     # Read the ROH data file for the specific ancestry
#     data <- fread(paste0(ANC, '_ROH.hom.indiv'))
#
#     # Print summary statistics for the number of segments (NSEG), total length (KB), and average length (KBAVG)
#     cat(sprintf(
#         '%s:\n\tNSEG = %d - %d\n\tKB = %.2f - %.2f\n\tKBAVG = %.2f - %.2f\n\n',
#         ANC,                           # Ancestry code
#         min(data$NSEG, na.rm = TRUE),   # Minimum number of segments
#         max(data$NSEG, na.rm = TRUE),   # Maximum number of segments
#         min(data$KB, na.rm = TRUE),     # Minimum total length of ROH segments (KB)
#         max(data$KB, na.rm = TRUE),     # Maximum total length of ROH segments (KB)
#         min(data$KBAVG, na.rm = TRUE),  # Minimum average length of ROH segments (KBAVG)
#         max(data$KBAVG, na.rm = TRUE)   # Maximum average length of ROH segments (KBAVG)
#     ))
# }
# Out:
# AAC:
# 	NSEG = 0 - 43
# 	KB = 0.00 - 182513.00
# 	KBAVG = 0.00 - 8347.52
#
# AFR:
# 	NSEG = 0 - 59
# 	KB = 0.00 - 281232.00
# 	KBAVG = 0.00 - 9508.29
#
# AJ:
# 	NSEG = 0 - 76
# 	KB = 0.00 - 523356.00
# 	KBAVG = 0.00 - 10188.50
#
# AMR:
# 	NSEG = 0 - 54
# 	KB = 0.00 - 297867.00
# 	KBAVG = 0.00 - 13152.40
#
# CAS:
# 	NSEG = 0 - 109
# 	KB = 0.00 - 402287.00
# 	KBAVG = 0.00 - 5074.36
#
# EAS:
# 	NSEG = 0 - 45
# 	KB = 0.00 - 132146.00
# 	KBAVG = 0.00 - 6399.77
#
# EUR:
# 	NSEG = 0 - 78
# 	KB = 0.00 - 291614.00
# 	KBAVG = 0.00 - 9869.45
#
# MDE:
# 	NSEG = 0 - 100
# 	KB = 0.00 - 330986.00
# 	KBAVG = 0.00 - 4178.68
#
# SAS:
# 	NSEG = 0 - 90
# 	KB = 0.00 - 310976.00
# 	KBAVG = 0.00 - 4756.36

# %% [markdown]
# ## Suppl. Figure 2 - KB (SROH) vs. NSEG (NROH) Plots with fixed axis

# %%
# Set the maximum y-axis value to 430,000 and the maximum x-axis value to 110 for a plot.
max_y = 430000 # max_y sets the upper limit for the y-axis (NROH - NSEG)
max_x = 110 # max_x sets the upper limit for the x-axis (SROH - KB)

# %%
# List of ancestries to loop through
for ANC in ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'MDE', 'SAS']:
    
    # Read the ROH data for the specific ancestry
    df = pd.read_csv(f"{ANC}_ROH.hom.indiv", delim_whitespace=True)
    
    # Filter for individuals with valid phenotype (PHE >= 0)
    df2 = df[df["PHE"] >= 0]
    
    # Create the scatter plot (SROH vs. NROH)
    plt.figure(figsize=(8, 6))  # Create a new figure for each plot
    plot = sns.scatterplot(data=df2, x="KB", y="NSEG", hue="PHE").set(title=f'{ANC}')
    
    # Set axis limits for the plot
    plt.ylim(0, max_x)  # Set y-axis limit (Number of ROH segments)
    plt.xlim(0, max_y)  # Set x-axis limit (Length of ROH segments in KB)
    
    # Label the x and y axes
    plt.xlabel("SROH (SROH of ROH segments in KB)")
    plt.ylabel("NROH (Number of ROH segments)")
    
    # Output the plot inline
    plt.show()  # Show the plot inline
    
    # Save the plot as a high-resolution JPEG file
    plt.savefig(f"kb_nseg_{ANC}_fixed.jpg", dpi=300)
    
    # Clear the current figure to avoid overlap in the next plot
    plt.clf()

# %% [markdown]
# ## Suppl. Figure 3 - AVROH vs. NROH Plots

# %%
# %%R
#
# # Loop over each ancestry and read the individual-level ROH data
# for (ANC in c('AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'MDE', 'SAS')) {
#
#     # Read the individual-level ROH data for the specified ancestry
#     data = fread(paste0(ANC, '_ROH.hom.indiv'))
#
#     # Print the ancestry code and summary statistics:
#     # - Minimum and maximum number of ROH segments (NSEG)
#     # - Minimum and maximum total ROH length (KB)
#     # - Minimum and maximum average ROH length (KBAVG)
#     cat(sprintf('%s :\tNSEG = %s - %s\n\tKB = %s - %s\n\tKBAVG = %s - %s\n',
#                 ANC,
#                 min(data$NSEG),    # Minimum number of ROH segments
#                 max(data$NSEG),    # Maximum number of ROH segments
#                 min(data$KB),      # Minimum total length of ROH segments
#                 max(data$KB),      # Maximum total length of ROH segments
#                 min(data$KBAVG),   # Minimum average ROH segment length
#                 max(data$KBAVG)    # Maximum average ROH segment length
#                ))
# }
# Out:
# AAC :	NSEG = 0 - 43
# 	KB = 0 - 182513
# 	KBAVG = 0 - 8347.52
# AFR :	NSEG = 0 - 59
# 	KB = 0 - 281232
# 	KBAVG = 0 - 9508.29
# AJ :	NSEG = 0 - 76
# 	KB = 0 - 523356
# 	KBAVG = 0 - 10188.5
# AMR :	NSEG = 0 - 54
# 	KB = 0 - 297867
# 	KBAVG = 0 - 13152.4
# CAS :	NSEG = 0 - 109
# 	KB = 0 - 402287
# 	KBAVG = 0 - 5074.36
# EAS :	NSEG = 0 - 45
# 	KB = 0 - 132146
# 	KBAVG = 0 - 6399.77
# EUR :	NSEG = 0 - 78
# 	KB = 0 - 291614
# 	KBAVG = 0 - 9869.45
# MDE :	NSEG = 0 - 100
# 	KB = 0 - 330986
# 	KBAVG = 0 - 4178.68
# SAS :	NSEG = 0 - 90
# 	KB = 0 - 310976
# 	KBAVG = 0 - 4756.36

# %%
# Set the maximum y-axis value to 21,000 and the maximum x-axis value to 110 for a plot.
max_y = 21000 # max_y sets the upper limit for the y-axis (NROH - NSEG)
max_x = 110 # max_x sets the upper limit for the x-axis (AVROH - KB)

# %%
# List of ancestries to loop through
for ANC in ['AAC', 'AFR', 'AJ', 'AMR', 'CAS', 'EAS', 'EUR', 'MDE', 'SAS']:
    
    # Read the ROH data for the specific ancestry
    df = pd.read_csv(f"{ANC}_ROH.hom.indiv", delim_whitespace=True)
    
    # Filter for individuals with valid phenotype (PHE >= 0)
    df2 = df[df["PHE"] >= 0]
    
    # Create the scatter plot (KBAVG vs. NSEG)
    plt.figure(figsize=(8, 6))  # Create a new figure for each plot
    plot = sns.scatterplot(data=df2, x="KBAVG", y="NSEG", hue="PHE").set(title=f'{ANC}')
    
    # Set axis limits for the plot
    plt.ylim(0, max_x)  # Set y-axis limit (Number of ROH segments)
    plt.xlim(0, max_y)  # Set x-axis limit (Average length of ROH segments in KB)
    
    # Label the x and y axes
    plt.xlabel("AVROH (Average Length of ROH segments in KB)")
    plt.ylabel("NROH (Number of ROH segments)")
    
    # Output the plot inline
    plt.show()  # Show the plot inline (e.g., in Jupyter Notebook)
    
    # Save the plot as a high-resolution JPEG file
    plt.savefig(f"kbavg_nseg_{ANC}_fixed.jpg", dpi=300)
    
    # Clear the current figure to avoid overlap in the next plot
    plt.clf()

# %% [markdown]
# # Suppl. Table 4 - Imputed Age Information

# %% [markdown]
# ## Generate COVAR file per ancestry

# %%
# %%R
#
# # List of ancestries to loop through
# ancestries <- c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Loop over each ancestry to process clinical and PCA data
# for (ANC in ancestries) {
#
#     # Load clinical data
#     clinical <- fread("master_key_release6_final.csv")
#     colnames(clinical)[2] <- "IID"  # Rename column 2 to 'IID' for consistency with PCA data
#
#     # Load PCA data for the specific ancestry
#     pca <- fread(paste0(ANC, "_release6.eigenvec"))
#
#     # Merge clinical data with PCA data by 'IID' (Individual ID)
#     merged <- merge(clinical, pca, by = "IID")
#
#     # Rename relevant columns for consistency and clarity
#     colnames(merged)[8] <- "SEX"  # Rename column 8 to 'SEX'
#     colnames(merged)[10] <- "AOO"  # Rename column 10 to 'AOO' (Age of Onset)
#
#     # Select relevant columns for the COVAR file
#     COVAR <- merged[, .(IID, SEX, age, PC1, PC2, PC3, PC4, PC5, PC6, PC7, PC8, PC9, PC10, AOO)]
#
#     # Write the COVAR file for each ancestry
#     fwrite(COVAR, paste0(ANC, "_COVAR.txt"))
# }

# %% [markdown]
# ## Extract Age ( Mean ± SD) for Each Ancestry

# %%
# %%R
#
# # List of ancestries to loop through
# ancestries <- c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Initialize an empty data frame to store results
# results <- data.frame()
#
# # Loop over each ancestry
# for (ANC in ancestries) {
#
#     # Load individual ROH data for the specific ancestry
#     data <- fread(paste0(ANC, "_ROH.hom.indiv"), header = TRUE)
#
#     # Filter data to exclude rows with missing phenotype (-9)
#     dat <- data[data$PHE != -9, ]
#
#     # Recode phenotype: subtract 1 to convert PHE values from 1/2 to 0 (control) / 1 (case)
#     dat$PHE <- dat$PHE - 1
#
#     # Load COVAR data for the same ancestry
#     cov <- fread(paste0(ANC, "_COVAR.txt"), header = TRUE)
#
#     # Merge the ROH data with COVAR data by "IID"
#     merged <- merge(dat, cov, by = "IID")
#
#     # Impute missing age: replace NA values with the mean age (rounded to nearest integer)
#     merged_impute_age <- merged
#     merged_impute_age[is.na(merged$age), ]$age <- round(mean(merged$age, na.rm = TRUE), 0)
#
#     # Calculate statistics:
#     # - ALL: Total number of individuals with age data
#     # - MISSING: Number of individuals with missing age before imputation
#     # - MEAN: Mean age after imputing missing values
#     # - SD: Standard deviation of age
#     ALL <- length(merged$age)
#     MISSING <- sum(is.na(merged$age))
#     MEAN <- round(mean(merged$age, na.rm = TRUE), 0)
#     SD <- round(sd(merged$age, na.rm = TRUE), 0)
#
#     # Consolidate results for the current ancestry
#     row <- data.frame(ANC = ANC, N = ALL, Missing_age = MISSING, Mean = MEAN, Sd = SD)
#     results <- rbind(results, row)
# }
#
# # Set the column names for the results data frame
# colnames(results) <- c("ANC", "N", "Missing_age", "Mean", "SD")
#
# # Write the results of the missing age analysis to a file for each ancestry
# fwrite(results, "missing_age_summary.txt")

# %%
# %%R
#
# # Display the summary of missing age statistics for each ancestry
# results
# Out:
#   ANC     N Missing_age Mean SD
# 1 AAC  1060         154   66 10
# 2 AFR  2548        1493   63 15
# 3  AJ  1459         267   69 10
# 4 AMR   502         105   60 12
# 5 CAS   532         152   57 10
# 6 EAS  3839        1132   64 11
# 7 EUR 19184        5438   66 11
# 8 MDE   234          18   65 13
# 9 SAS   315         109   57 16

# %% [markdown]
# # Exploration of Homozygosity Parameters (with recessive genes)

# %% [markdown]
# ## Calculate FROH for all individuals

# %%
# %%R
#
# # List of ancestries to loop through
# ancestries <- c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Loop through each ancestry
# for (ANC in ancestries) {
#
#     # Read the individual-level ROH data file for the specific ancestry
#     data <- fread(paste0(ANC, "_ROH.hom.indiv"), header = TRUE)
#
#     # Calculate FROH: total length of ROH segments (KB) divided by the length of the human autosomal genome (GRCh38)
#     data$FROH <- round(data$KB / 2886428, digits = 5)  # Autosomal genome length: 2,886,428 KB
#
#     # Write the updated data with FROH to a new file
#     fwrite(data, paste0(ANC, "_ROH_withFROH.hom.indiv"))
# }

# %% [markdown]
# ## Generate COVAR file per ancestry

# %%
# %%R
#
# # List of ancestries to loop through
# ancestries <- c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Loop over each ancestry to process clinical and PCA data
# for (ANC in ancestries) {
#
#     # Load clinical data
#     clinical <- fread("master_key_release6_final.csv")
#     colnames(clinical)[2] <- "IID"  # Rename column 2 to 'IID' for consistency with PCA data
#
#     # Load PCA data for the specific ancestry
#     pca <- fread(paste0(ANC, "_release6.eigenvec"))
#
#     # Merge clinical data with PCA data by 'IID' (Individual ID)
#     merged <- merge(clinical, pca, by = "IID")
#
#     # Rename relevant columns for consistency and clarity
#     colnames(merged)[8] <- "SEX"  # Rename column 8 to 'SEX'
#     colnames(merged)[10] <- "AOO"  # Rename column 10 to 'AOO' (Age of Onset)
#
#     # Select relevant columns for the COVAR file
#     COVAR <- merged[, .(IID, SEX, age, PC1, PC2, PC3, PC4, PC5, PC6, PC7, PC8, PC9, PC10, AOO)]
#
#     # Write the COVAR file for each ancestry
#     fwrite(COVAR, paste0(ANC, "_COVAR.txt"))
# }

# %% [markdown]
# ## Table 1 - Cases vs. controls

# %% [markdown]
# ### T-test: mean values

# %%
# %%R
#
# # List of ancestries to loop through
# ancestries <- c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Initialize an empty data frame to store results
# results <- data.frame()
#
# # Loop through each ancestry
# for (ANC in ancestries) {
#
#     # Load individual ROH data with FROH for the specific ancestry
#     data <- fread(paste0(ANC, "_ROH_withFROH.hom.indiv"), header = TRUE)
#
#     # Recode Cases and Controls: PHE == -9 is missing data, so we filter those out
#     dat <- data[data$PHE != -9, ]
#     dat$PHE <- dat$PHE - 1  # Recode phenotype: 1 -> control (0), 2 -> case (1)
#
#     # Summarize data by phenotype (case/control) using group_by and summarise from dplyr
#     data_tidy <- dat %>%
#         group_by(PHE) %>%
#         summarise(
#             NSEG_mean = mean(NSEG, na.rm = TRUE),
#             KB_mean = mean(KB, na.rm = TRUE),
#             KBAVG_mean = mean(KBAVG, na.rm = TRUE),
#             NSEG_sd = sd(NSEG, na.rm = TRUE),
#             KB_sd = sd(KB, na.rm = TRUE),
#             KBAVG_sd = sd(KBAVG, na.rm = TRUE),
#             FROH_mean = mean(FROH, na.rm = TRUE),
#             FROH_sd = sd(FROH, na.rm = TRUE)
#         )
#
#     # Perform t-tests for the four parameters
#     model1_imp <- t.test(NSEG ~ PHE, data = dat)    # NROH
#     model2_imp <- t.test(KB ~ PHE, data = dat)      # SROH
#     model3_imp <- t.test(KBAVG ~ PHE, data = dat)   # AVROH
#     model4_imp <- t.test(FROH ~ PHE, data = dat)    # FROH
#
#     # Calculate mean, SD, and p-value for each parameter
#     # SROH (Sum of ROH lengths)
#     SROH_cases <- paste(round(data_tidy$KB_mean[2], 1), "±", round(data_tidy$KB_sd[2], 1))
#     SROH_controls <- paste(round(data_tidy$KB_mean[1], 1), "±", round(data_tidy$KB_sd[1], 1))
#     SROH_pvalue <- signif(model2_imp$p.value, 3)
#
#     # AVROH (Average ROH length)
#     AVROH_cases <- paste(round(data_tidy$KBAVG_mean[2], 1), "±", round(data_tidy$KBAVG_sd[2], 1))
#     AVROH_controls <- paste(round(data_tidy$KBAVG_mean[1], 1), "±", round(data_tidy$KBAVG_sd[1], 1))
#     AVROH_pvalue <- signif(model3_imp$p.value, 3)
#
#     # NROH (Number of ROH segments)
#     NROH_cases <- paste(round(data_tidy$NSEG_mean[2], 1), "±", round(data_tidy$NSEG_sd[2], 1))
#     NROH_controls <- paste(round(data_tidy$NSEG_mean[1], 1), "±", round(data_tidy$NSEG_sd[1], 1))
#     NROH_pvalue <- signif(model1_imp$p.value, 3)
#
#     # FROH (Genomic inbreeding coefficient)
#     FROH_cases <- paste(round(data_tidy$FROH_mean[2], 4), "±", signif(data_tidy$FROH_sd[2], 1))
#     FROH_controls <- paste(round(data_tidy$FROH_mean[1], 4), "±", signif(data_tidy$FROH_sd[1], 1))
#     FROH_pvalue <- signif(model4_imp$p.value, 3)
#
#     # Consolidate results for each ancestry
#     row <- c(ANC, SROH_cases, SROH_controls, SROH_pvalue,
#              AVROH_cases, AVROH_controls, AVROH_pvalue,
#              NROH_cases, NROH_controls, NROH_pvalue,
#              FROH_cases, FROH_controls, FROH_pvalue)
#
#     # Append the row to the results data frame
#     results <- rbind(results, row)
# }
#
# # Assign column names to the results data frame
# colnames(results) <- c("Ancestry", "SROH_cases", "SROH_controls", "SROH_pvalue",
#                        "AVROH_cases", "AVROH_controls", "AVROH_pvalue",
#                        "NROH_cases", "NROH_controls", "NROH_pvalue",
#                        "FROH_cases", "FROH_controls", "FROH_pvalue")
#
# # Save the results to a text file
# fwrite(results, "Pvalues_T-test_casesVScontrols.txt")
#
# # Display the results data frame
# results
# Out:
#   Ancestry        SROH_cases     SROH_controls SROH_pvalue     AVROH_cases
# 1      AAC  6330.5 ± 15828.5  4373.8 ± 10741.9      0.0656 1815.6 ± 1353.4
# 2      AFR  9820.3 ± 13817.2  8158.4 ± 12023.3     0.00232  2252.6 ± 858.7
# 3       AJ   22595 ± 25823.3 21501.1 ± 17549.3       0.345  2879.5 ± 870.1
# 4      AMR 15162.8 ± 28418.6 13186.3 ± 15927.9       0.327 2302.8 ± 1235.4
# 5      CAS 13658.5 ± 34079.3 19719.4 ± 40956.5       0.064    1885 ± 840.4
# 6      EAS   5188.6 ± 7891.7     7134.8 ± 9454    5.72e-12  1735.7 ± 798.7
# 7      EUR   6391.1 ± 8056.4    7053.2 ± 10929    6.29e-06  1907.7 ± 730.3
# 8      MDE   26001.8 ± 41078 11143.3 ± 13622.3    0.000667  2048.5 ± 736.5
# 9      SAS 12647.7 ± 21865.5 34198.7 ± 57886.9    4.08e-06  1995.5 ± 680.7
#    AVROH_controls AVROH_pvalue  NROH_cases NROH_controls NROH_pvalue
# 1   1580.9 ± 1158       0.0129   2.1 ± 3.1       1.7 ± 3      0.0939
# 2  2118.8 ± 945.2      0.00028     4 ± 4.1       3.3 ± 4    4.92e-05
# ...

# %% [markdown]
# ### Regression: beta values

# %%
# %%R
#
# # List of ancestries to loop through
# ancestries <- c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Initialize an empty data frame to store the results
# results <- data.frame()
#
# # Loop through each ancestry
# for (ANC in ancestries) {
#
#     # Load the individual ROH data with FROH for the specific ancestry
#     data <- fread(paste0(ANC, "_ROH_withFROH.hom.indiv"), header = TRUE)
#
#     # Recode Cases and Controls: Exclude rows where PHE == -9 (missing phenotype)
#     dat <- data[data$PHE != -9, ]
#     dat$PHE <- dat$PHE - 1  # Recode: PHE 1 -> control (0), PHE 2 -> case (1)
#
#     # Load the covariate data for the specific ancestry
#     cov <- fread(paste0(ANC, "_COVAR.txt"), header = TRUE)
#
#     # Merge ROH data with covariates by "IID" (Individual ID)
#     merged <- merge(dat, cov, by = "IID")
#
#     # Impute missing age with the mean age (rounded to nearest integer)
#     merged_impute_age <- merged
#     merged_impute_age[is.na(merged$age),]$age <- round(mean(merged$age, na.rm = TRUE), 0)
#
#     # Logistic regressions for 4 parameters (NROH, SROH, AVROH, FROH)
#
#     # NROH: Number of ROH segments
#     model1_imp <- glm(PHE ~ NSEG + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = merged_impute_age, family = "binomial")
#
#     # SROH: Sum of ROH lengths
#     model2_imp <- glm(PHE ~ KB + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = merged_impute_age, family = "binomial")
#
#     # AVROH: Average ROH length
#     model3_imp <- glm(PHE ~ KBAVG + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = merged_impute_age, family = "binomial")
#
#     # FROH: Genomic inbreeding coefficient
#     model4_imp <- glm(PHE ~ FROH + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = merged_impute_age, family = "binomial")
#
#     # Extract Beta and p-value for SROH
#     SROH_beta <- paste(signif(summary(model2_imp)$coef[2, 1], 3), "±", signif(summary(model2_imp)$coef[2, 2], 3))
#     SROH_pvalue <- signif(summary(model2_imp)$coef[2, 4], 3)
#
#     # Extract Beta and p-value for AVROH
#     AVROH_beta <- paste(signif(summary(model3_imp)$coef[2, 1], 3), "±", signif(summary(model3_imp)$coef[2, 2], 3))
#     AVROH_pvalue <- signif(summary(model3_imp)$coef[2, 4], 3)
#
#     # Extract Beta and p-value for NROH
#     NROH_beta <- paste(signif(summary(model1_imp)$coef[2, 1], 3), "±", signif(summary(model1_imp)$coef[2, 2], 3))
#     NROH_pvalue <- signif(summary(model1_imp)$coef[2, 4], 3)
#
#     # Extract Beta and p-value for FROH
#     FROH_beta <- paste(signif(summary(model4_imp)$coef[2, 1], 3), "±", signif(summary(model4_imp)$coef[2, 2], 3))
#     FROH_pvalue <- signif(summary(model4_imp)$coef[2, 4], 3)
#
#     # Consolidate results for each ancestry into a single row
#     row <- c(ANC, SROH_beta, SROH_pvalue, AVROH_beta, AVROH_pvalue,
#              NROH_beta, NROH_pvalue, FROH_beta, FROH_pvalue)
#
#     # Append the row to the results data frame
#     results <- rbind(results, row)
# }
#
# # Assign column names to the results data frame
# colnames(results) <- c("Ancestry", "SROH_Beta", "SROH_Pvalue",
#                        "AVROH_Beta", "AVROH_Pvalue",
#                        "NROH_Beta", "NROH_Pvalue",
#                        "FROH_Beta", "FROH_Pvalue")
#
# # Save the results to a text file
# fwrite(results, "Pvalues_regression_model_casesVScontrols.txt")
#
# # Display the results data frame
# results
# Out:
#   Ancestry            SROH_Beta SROH_Pvalue           AVROH_Beta AVROH_Pvalue
# 1      AAC  1.31e-05 ± 6.16e-06      0.0337  0.000176 ± 6.23e-05      0.00469
# 2      AFR  7.16e-06 ± 3.45e-06       0.038   0.000119 ± 5.1e-05       0.0194
# 3       AJ  2.03e-06 ± 2.66e-06       0.445   6.8e-05 ± 6.77e-05        0.316
# 4      AMR  4.35e-06 ± 4.61e-06       0.345 -8.68e-05 ± 7.64e-05        0.256
# 5      CAS -2.69e-07 ± 2.86e-06       0.925 -0.000157 ± 0.000121        0.194
# 6      EAS -9.94e-06 ± 5.41e-06      0.0661 -4.94e-05 ± 6.26e-05         0.43
# 7      EUR -8.48e-06 ± 1.68e-06    4.44e-07    -6.04e-05 ± 2e-05      0.00257
# 8      MDE   4.04e-05 ± 2.1e-05      0.0545  0.000453 ± 0.000302        0.134
# 9      SAS -1.67e-05 ± 4.83e-06    0.000544 -0.000261 ± 0.000152       0.0857
#            NROH_Beta NROH_Pvalue     FROH_Beta FROH_Pvalue
# 1     0.0476 ± 0.027      0.0774   37.8 ± 17.8      0.0337
# 2    0.0221 ± 0.0115      0.0539   20.7 ± 9.96      0.0379
# ...

# %% [markdown]
# ## Table 2 - Early- and late- onset cases vs. controls

# %% [markdown]
# ### T-test: mean values

# %%
# %%R
#
# # List of ancestries to loop through
# ancestries <- c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Initialize an empty data frame to store the results
# results <- data.frame()
#
# # Loop through each ancestry
# for (ANC in ancestries) {
#
#     # Load individual-level ROH data with FROH for the specific ancestry
#     data <- fread(paste0(ANC, "_ROH_withFROH.hom.indiv"), header = TRUE)
#
#     # Recode Cases and Controls: Remove rows where PHE == -9 (missing phenotype)
#     dat <- data[data$PHE != -9, ]
#     dat$PHE <- dat$PHE - 1  # Recode phenotype: PHE 1 -> control (0), PHE 2 -> case (1)
#
#     # Load covariate data for the specific ancestry
#     cov <- fread(paste0(ANC, "_COVAR.txt"), header = TRUE)
#
#     # Merge ROH data with covariates using "IID" as the key
#     merged <- merge(dat, cov, by = "IID")
#
#     # Impute missing age with the mean age (rounded to the nearest integer)
#     merged_impute_age <- merged
#     merged_impute_age[is.na(merged$age), ]$age <- round(mean(merged$age, na.rm = TRUE), 0)
#
#     # Split data into two subsets: Early-onset PD (EOPD) and Late-onset PD (LOPD)
#     early <- subset(merged_impute_age, PHE == 0 | AOO < 45)  # Cases with AOO < 45 vs. controls
#     late <- subset(merged_impute_age, PHE == 0 | AOO >= 45)  # Cases with AOO >= 45 vs. controls
#
#     # Summarize mean and SD for each group (cases and controls) in both subsets
#     early_tidy <- early %>%
#         group_by(PHE) %>%
#         summarise(Number = n(),
#                   NSEG_mean = mean(NSEG),
#                   KB_mean = mean(KB),
#                   KBAVG_mean = mean(KBAVG),
#                   NSEG_sd = sd(NSEG),
#                   KB_sd = sd(KB, na.rm = TRUE),
#                   KBAVG_sd = sd(KBAVG, na.rm = TRUE),
#                   FROH_mean = mean(FROH, na.rm = TRUE),
#                   FROH_sd = sd(FROH, na.rm = TRUE))
#
#     late_tidy <- late %>%
#         group_by(PHE) %>%
#         summarise(Number = n(),
#                   NSEG_mean = mean(NSEG),
#                   KB_mean = mean(KB),
#                   KBAVG_mean = mean(KBAVG),
#                   NSEG_sd = sd(NSEG),
#                   KB_sd = sd(KB, na.rm = TRUE),
#                   KBAVG_sd = sd(KBAVG, na.rm = TRUE),
#                   FROH_mean = mean(FROH, na.rm = TRUE),
#                   FROH_sd = sd(FROH, na.rm = TRUE))
#
#     # Perform logistic regression models for each subset and each parameter
#     model1_early <- glm(PHE ~ NSEG + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = early, family = "binomial")
#     model1_late <- glm(PHE ~ NSEG + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = late, family = "binomial")
#
#     model2_early <- glm(PHE ~ KB + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = early, family = "binomial")
#     model2_late <- glm(PHE ~ KB + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = late, family = "binomial")
#
#     model3_early <- glm(PHE ~ KBAVG + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = early, family = "binomial")
#     model3_late <- glm(PHE ~ KBAVG + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = late, family = "binomial")
#
#     model4_early <- glm(PHE ~ FROH + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = early, family = "binomial")
#     model4_late <- glm(PHE ~ FROH + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = late, family = "binomial")
#
#     # Number of cases and controls
#     earlycases_controls <- paste0(early_tidy$Number[2], " (", early_tidy$Number[1], ")")
#     latecases_controls <- paste0(late_tidy$Number[2], " (", late_tidy$Number[1], ")")
#
#     # Mean, SD, and p-value calculation for each parameter:
#     # SROH (Sum of ROH lengths)
#     SROH_case_early <- paste(round(early_tidy$KB_mean[2], 1), "±", round(early_tidy$KB_sd[2], 1))
#     SROH_case_late <- paste(round(late_tidy$KB_mean[2], 1), "±", round(late_tidy$KB_sd[2], 1))
#     SROH_controls <- paste(round(late_tidy$KB_mean[1], 1), "±", round(late_tidy$KB_sd[1], 1))
#     SROH_early <- signif(summary(model2_early)$coef[2, 4], 3)
#     SROH_late <- signif(summary(model2_late)$coef[2, 4], 3)
#
#     # AVROH (Average ROH length)
#     AVROH_case_early <- paste(round(early_tidy$KBAVG_mean[2], 1), "±", round(early_tidy$KBAVG_sd[2], 1))
#     AVROH_case_late <- paste(round(late_tidy$KBAVG_mean[2], 1), "±", round(late_tidy$KBAVG_sd[2], 1))
#     AVROH_controls <- paste(round(late_tidy$KBAVG_mean[1], 1), "±", round(late_tidy$KBAVG_sd[1], 1))
#     AVROH_early <- signif(summary(model3_early)$coef[2, 4], 3)
#     AVROH_late <- signif(summary(model3_late)$coef[2, 4], 3)
#
#     # NROH (Number of ROH segments)
#     NROH_case_early <- paste(round(early_tidy$NSEG_mean[2], 1), "±", round(early_tidy$NSEG_sd[2], 1))
#     NROH_case_late <- paste(round(late_tidy$NSEG_mean[2], 1), "±", round(late_tidy$NSEG_sd[2], 1))
#     NROH_controls <- paste(round(late_tidy$NSEG_mean[1], 1), "±", round(late_tidy$NSEG_sd[1], 1))
#     NROH_early <- signif(summary(model1_early)$coef[2, 4], 3)
#     NROH_late <- signif(summary(model1_late)$coef[2, 4], 3)
#
#     # FROH (Genomic inbreeding coefficient)
#     FROH_case_early <- paste(round(early_tidy$FROH_mean[2], 4), "±", signif(early_tidy$FROH_sd[2], 2))
#     FROH_case_late <- paste(round(late_tidy$FROH_mean[2], 4), "±", signif(late_tidy$FROH_sd[2], 2))
#     FROH_controls <- paste(round(late_tidy$FROH_mean[1], 4), "±", signif(late_tidy$FROH_sd[1], 2))
#     FROH_early <- signif(summary(model4_early)$coef[2, 4], 3)
#     FROH_late <- signif(summary(model4_late)$coef[2, 4], 3)
#
#     # Consolidate results for each ancestry and onset type (early and late)
#     row1 <- c(ANC, "EOPD", earlycases_controls,
#               SROH_case_early, SROH_controls, SROH_early,
#               AVROH_case_early, AVROH_controls, AVROH_early,
#               NROH_case_early, NROH_controls, NROH_early,
#               FROH_case_early, FROH_controls, FROH_early)
#
#     row2 <- c(ANC, "LOPD", latecases_controls,
#               SROH_case_late, SROH_controls, SROH_late,
#               AVROH_case_late, AVROH_controls, AVROH_late,
#               NROH_case_late, NROH_controls, NROH_late,
#               FROH_case_late, FROH_controls, FROH_late)
#
#     # Append rows for both early and late onset
#     row <- rbind(row1, row2)
#     results <- rbind(results, row)
# }
#
# # Assign column names to the results data frame
# colnames(results) <- c("Ancestry", "Onset", "Cases_Controls",
#                        "SROH_Case", "SROH_Controls", "SROH_Pvalue",
#                        "AVROH_Case", "AVROH_Controls", "AVROH_Pvalue",
#                        "NROH_Case", "NROH_Controls", "NROH_Pvalue",
#                        "FROH_Case", "FROH_Controls", "FROH_Pvalue")
#
# # Save the results to a text file
# fwrite(results, "Pvalues_regression_model_Subset_casesVScontrols.txt")
#
# # Display the results data frame
# results
# Out:
#       Ancestry Onset Cases_Controls         SROH_Case     SROH_Controls
# row1       AAC  EOPD       21 (804)  8245.1 ± 15765.5  4373.8 ± 10741.9
# row2       AAC  LOPD      128 (804)  5091.8 ± 16488.7  4373.8 ± 10741.9
# row11      AFR  EOPD      21 (1631) 25590.9 ± 59156.1  8158.4 ± 12023.3
# row21      AFR  LOPD     137 (1631)    11624 ± 8641.2  8158.4 ± 12023.3
# row12       AJ  EOPD       83 (458) 20847.5 ± 17799.5 21501.1 ± 17549.3
# row22       AJ  LOPD      719 (458) 22976.1 ± 27367.4 21501.1 ± 17549.3
# row13      AMR  EOPD       91 (139)   19577 ± 40777.5 13186.3 ± 15927.9
# row23      AMR  LOPD      163 (139) 13160.7 ± 21016.2 13186.3 ± 15927.9
# row14      CAS  EOPD       53 (267)    9192.6 ± 20794 19719.4 ± 40956.5
# row24      CAS  LOPD       57 (267)   5803.5 ± 6784.5 19719.4 ± 40956.5
# row15      EAS  EOPD     243 (2302)   5377.1 ± 8088.1     7134.8 ± 9454
# row25      EAS  LOPD     455 (2302)   4759.6 ± 6072.4     7134.8 ± 9454
# ...

# %% [markdown]
# ### Regression: beta values

# %%
# %%R
#
# # Define ancestries to loop through
# ancestries <- c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Initialize an empty data frame to store the results
# results <- data.frame()
#
# # Loop through each ancestry in the list
# for (ANC in ancestries) {
#
#     # Load ROH data for the current ancestry with FROH (fractional ROH)
#     data <- fread(paste0(ANC, "_ROH_withFROH.hom.indiv"), header = TRUE)
#
#     # Recode cases and controls (PHE 1 -> control (0), PHE 2 -> case (1))
#     dat <- data[data$PHE != -9, ]  # Exclude individuals with missing phenotype
#     dat$PHE <- dat$PHE - 1
#
#     # Load covariate data for the same ancestry
#     cov <- fread(paste0(ANC, "_COVAR.txt"), header = TRUE)
#
#     # Merge ROH and covariate data by IID (individual ID)
#     merged <- merge(dat, cov, by = "IID")
#
#     # Impute missing age values with the mean age (rounded)
#     merged_impute_age <- merged
#     merged_impute_age[is.na(merged_impute_age$age), ]$age <- round(mean(merged_impute_age$age, na.rm = TRUE), 0)
#
#     # Split data into two groups: Early-onset PD (AOO < 45) and Late-onset PD (AOO >= 45)
#     early <- subset(merged_impute_age, PHE == 0 | AOO < 45)  # Early-onset cases vs controls
#     late <- subset(merged_impute_age, PHE == 0 | AOO >= 45)  # Late-onset cases vs controls
#
#     # Summarize mean and standard deviation for each ROH parameter (NSEG, KB, KBAVG, FROH) per group
#     early_summary <- early %>%
#         group_by(PHE) %>%
#         summarise(Number = n(),
#                   NSEG_mean = mean(NSEG),
#                   KB_mean = mean(KB),
#                   KBAVG_mean = mean(KBAVG),
#                   NSEG_sd = sd(NSEG),
#                   KB_sd = sd(KB, na.rm = TRUE),
#                   KBAVG_sd = sd(KBAVG, na.rm = TRUE),
#                   FROH_mean = mean(FROH, na.rm = TRUE),
#                   FROH_sd = sd(FROH, na.rm = TRUE))
#
#     late_summary <- late %>%
#         group_by(PHE) %>%
#         summarise(Number = n(),
#                   NSEG_mean = mean(NSEG),
#                   KB_mean = mean(KB),
#                   KBAVG_mean = mean(KBAVG),
#                   NSEG_sd = sd(NSEG),
#                   KB_sd = sd(KB, na.rm = TRUE),
#                   KBAVG_sd = sd(KBAVG, na.rm = TRUE),
#                   FROH_mean = mean(FROH, na.rm = TRUE),
#                   FROH_sd = sd(FROH, na.rm = TRUE))
#
#     # Perform logistic regression for each ROH parameter, adjusting for PCs, sex, and age
#     # Models for Early-onset cases
#     model1_early <- glm(PHE ~ NSEG + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = early, family = "binomial")
#     model2_early <- glm(PHE ~ KB + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = early, family = "binomial")
#     model3_early <- glm(PHE ~ KBAVG + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = early, family = "binomial")
#     model4_early <- glm(PHE ~ FROH + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = early, family = "binomial")
#
#     # Models for Late-onset cases
#     model1_late <- glm(PHE ~ NSEG + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = late, family = "binomial")
#     model2_late <- glm(PHE ~ KB + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = late, family = "binomial")
#     model3_late <- glm(PHE ~ KBAVG + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = late, family = "binomial")
#     model4_late <- glm(PHE ~ FROH + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = late, family = "binomial")
#
#     # Number of cases and controls for each onset group
#     early_cases_controls <- paste0(early_summary$Number[2], " (", early_summary$Number[1], ")")
#     late_cases_controls <- paste0(late_summary$Number[2], " (", late_summary$Number[1], ")")
#
#     # Collect summary statistics (mean, SD) and p-values for each ROH parameter:
#     # SROH (Sum of ROH lengths)
#     SROH_case_early <- paste(round(early_summary$KB_mean[2], 1), "±", round(early_summary$KB_sd[2], 1))
#     SROH_case_late <- paste(round(late_summary$KB_mean[2], 1), "±", round(late_summary$KB_sd[2], 1))
#     SROH_controls <- paste(round(late_summary$KB_mean[1], 1), "±", round(late_summary$KB_sd[1], 1))
#     SROH_early_pvalue <- signif(summary(model2_early)$coef[2, 4], 3)
#     SROH_late_pvalue <- signif(summary(model2_late)$coef[2, 4], 3)
#
#     # AVROH (Average ROH length)
#     AVROH_case_early <- paste(round(early_summary$KBAVG_mean[2], 1), "±", round(early_summary$KBAVG_sd[2], 1))
#     AVROH_case_late <- paste(round(late_summary$KBAVG_mean[2], 1), "±", round(late_summary$KBAVG_sd[2], 1))
#     AVROH_controls <- paste(round(late_summary$KBAVG_mean[1], 1), "±", round(late_summary$KBAVG_sd[1], 1))
#     AVROH_early_pvalue <- signif(summary(model3_early)$coef[2, 4], 3)
#     AVROH_late_pvalue <- signif(summary(model3_late)$coef[2, 4], 3)
#
#     # NROH (Number of ROH segments)
#     NROH_case_early <- paste(round(early_summary$NSEG_mean[2], 1), "±", round(early_summary$NSEG_sd[2], 1))
#     NROH_case_late <- paste(round(late_summary$NSEG_mean[2], 1), "±", round(late_summary$NSEG_sd[2], 1))
#     NROH_controls <- paste(round(late_summary$NSEG_mean[1], 1), "±", round(late_summary$NSEG_sd[1], 1))
#     NROH_early_pvalue <- signif(summary(model1_early)$coef[2, 4], 3)
#     NROH_late_pvalue <- signif(summary(model1_late)$coef[2, 4], 3)
#
#     # FROH (Genomic inbreeding coefficient)
#     FROH_case_early <- paste(round(early_summary$FROH_mean[2], 4), "±", signif(early_summary$FROH_sd[2], 2))
#     FROH_case_late <- paste(round(late_summary$FROH_mean[2], 4), "±", signif(late_summary$FROH_sd[2], 2))
#     FROH_controls <- paste(round(late_summary$FROH_mean[1], 4), "±", signif(late_summary$FROH_sd[1], 2))
#     FROH_early_pvalue <- signif(summary(model4_early)$coef[2, 4], 3)
#     FROH_late_pvalue <- signif(summary(model4_late)$coef[2, 4], 3)
#
#     # Consolidate results into two rows (early-onset and late-onset)
#     row_early <- c(ANC, "EOPD", early_cases_controls,
#                    SROH_case_early, SROH_controls, SROH_early_pvalue,
#                    AVROH_case_early, AVROH_controls, AVROH_early_pvalue,
#                    NROH_case_early, NROH_controls, NROH_early_pvalue,
#                    FROH_case_early, FROH_controls, FROH_early_pvalue)
#
#     row_late <- c(ANC, "LOPD", late_cases_controls,
#                   SROH_case_late, SROH_controls, SROH_late_pvalue,
#                   AVROH_case_late, AVROH_controls, AVROH_late_pvalue,
#                   NROH_case_late, NROH_controls, NROH_late_pvalue,
#                   FROH_case_late, FROH_controls, FROH_late_pvalue)
#
#     # Append rows to results
#     results <- rbind(results, row_early, row_late)
# }
#
# # Assign meaningful column names to the results data frame
# colnames(results) <- c("Ancestry", "Onset", "Cases_Controls",
#                        "SROH_Case", "SROH_Controls", "SROH_Pvalue",
#                        "AVROH_Case", "AVROH_Controls", "AVROH_Pvalue",
#                        "NROH_Case", "NROH_Controls", "NROH_Pvalue",
#                        "FROH_Case", "FROH_Controls", "FROH_Pvalue")
#
# # Write the final results to a file
# fwrite(results, "Pvalues_regression_model_Subset_casesVScontrols.txt")
#
# # Display the results data frame
# results
# Out:
#    Ancestry Onset Cases_Controls         SROH_Case     SROH_Controls
# 1       AAC  EOPD       21 (804)  8245.1 ± 15765.5  4373.8 ± 10741.9
# 2       AAC  LOPD      128 (804)  5091.8 ± 16488.7  4373.8 ± 10741.9
# 3       AFR  EOPD      21 (1631) 25590.9 ± 59156.1  8158.4 ± 12023.3
# 4       AFR  LOPD     137 (1631)    11624 ± 8641.2  8158.4 ± 12023.3
# 5        AJ  EOPD       83 (458) 20847.5 ± 17799.5 21501.1 ± 17549.3
# 6        AJ  LOPD      719 (458) 22976.1 ± 27367.4 21501.1 ± 17549.3
# 7       AMR  EOPD       91 (139)   19577 ± 40777.5 13186.3 ± 15927.9
# 8       AMR  LOPD      163 (139) 13160.7 ± 21016.2 13186.3 ± 15927.9
# 9       CAS  EOPD       53 (267)    9192.6 ± 20794 19719.4 ± 40956.5
# 10      CAS  LOPD       57 (267)   5803.5 ± 6784.5 19719.4 ± 40956.5
# 11      EAS  EOPD     243 (2302)   5377.1 ± 8088.1     7134.8 ± 9454
# 12      EAS  LOPD     455 (2302)   4759.6 ± 6072.4     7134.8 ± 9454
# 13      EUR  EOPD    1042 (7505)    6727.8 ± 11991    7053.2 ± 10929
# ...

# %% [markdown]
# ## Table 3 - Early- vs. late- onset

# %% [markdown]
# ### T-test: mean values

# %%
# %%R
#
# # List of ancestries to loop through
# ancestries <- c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Initialize an empty data frame to store results
# results <- data.frame(NULL)
#
# # Loop through each ancestry
# for (ANC in ancestries) {
#     # Load ROH data with FROH (fractional ROH)
#     data <- fread(paste0(ANC, "_ROH_withFROH.hom.indiv"), header = TRUE)
#
#     # Recode cases and controls (exclude individuals with missing PHE)
#     dat <- data[data$PHE != -9, ]
#     dat$PHE <- dat$PHE - 1  # Recode PHE as 0 (controls) and 1 (cases)
#
#     # Load covariate data
#     cov <- fread(paste0(ANC, "_COVAR.txt"), header = TRUE)
#
#     # Merge ROH and covariate data by IID
#     merged <- merge(dat, cov, by = "IID")
#
#     # Impute missing age values with the mean (rounded to nearest integer)
#     merged_impute_age <- merged
#     merged_impute_age[is.na(merged_impute_age$age), ]$age <- round(mean(merged_impute_age$age, na.rm = TRUE), 0)
#
#     # Subset only PD cases and recode age of onset (AOO) as early (EOPD) and late onset (LOPD)
#     PD_cases <- subset(merged_impute_age, PHE == 1)
#     PD_cases$AOO_categoric <- ifelse(PD_cases$AOO < 45, "EOPD", ifelse(PD_cases$AOO >= 45, "LOPD", NA))
#     PD_cases <- PD_cases[!is.na(PD_cases$AOO_categoric), ]  # Exclude cases with missing AOO categoric values
#
#     # Perform t-tests for each ROH parameter (NSEG, KB, KBAVG, FROH)
#     ttest_NSEG <- t.test(NSEG ~ AOO_categoric, data = PD_cases)
#     ttest_KB <- t.test(KB ~ AOO_categoric, data = PD_cases)
#     ttest_KBAVG <- t.test(KBAVG ~ AOO_categoric, data = PD_cases)
#     ttest_FROH <- t.test(FROH ~ AOO_categoric, data = PD_cases)
#
#     # Means and SDs for early-onset and late-onset cases
#     summary_stats <- PD_cases %>%
#         group_by(AOO_categoric) %>%
#         summarise(
#             NSEG_mean = round(mean(NSEG), 1),
#             NSEG_sd = round(sd(NSEG), 1),
#             KB_mean = round(mean(KB), 1),
#             KB_sd = round(sd(KB), 1),
#             KBAVG_mean = round(mean(KBAVG), 1),
#             KBAVG_sd = round(sd(KBAVG), 1),
#             FROH_mean = round(mean(FROH, na.rm = TRUE), 4),
#             FROH_sd = round(sd(FROH, na.rm = TRUE), 4)
#         )
#
#     # Extract t-test p-values
#     NSEG_pvalue <- signif(ttest_NSEG$p.value, 3)
#     KB_pvalue <- signif(ttest_KB$p.value, 3)
#     KBAVG_pvalue <- signif(ttest_KBAVG$p.value, 3)
#     FROH_pvalue <- signif(ttest_FROH$p.value, 3)
#
#     # Format entries for results table
#     # NSEG (Number of ROH segments)
#     NSEG_EOPD <- paste(summary_stats$NSEG_mean[1], "±", summary_stats$NSEG_sd[1])
#     NSEG_LOPD <- paste(summary_stats$NSEG_mean[2], "±", summary_stats$NSEG_sd[2])
#
#     # KB (Sum of ROH lengths)
#     KB_EOPD <- paste(summary_stats$KB_mean[1], "±", summary_stats$KB_sd[1])
#     KB_LOPD <- paste(summary_stats$KB_mean[2], "±", summary_stats$KB_sd[2])
#
#     # KBAVG (Average ROH length)
#     KBAVG_EOPD <- paste(summary_stats$KBAVG_mean[1], "±", summary_stats$KBAVG_sd[1])
#     KBAVG_LOPD <- paste(summary_stats$KBAVG_mean[2], "±", summary_stats$KBAVG_sd[2])
#
#     # FROH (Genomic inbreeding coefficient)
#     FROH_EOPD <- paste(summary_stats$FROH_mean[1], "±", summary_stats$FROH_sd[1])
#     FROH_LOPD <- paste(summary_stats$FROH_mean[2], "±", summary_stats$FROH_sd[2])
#
#     # Consolidate results into a row
#     row <- c(ANC,
#              NSEG_EOPD, NSEG_LOPD, NSEG_pvalue,
#              KB_EOPD, KB_LOPD, KB_pvalue,
#              KBAVG_EOPD, KBAVG_LOPD, KBAVG_pvalue,
#              FROH_EOPD, FROH_LOPD, FROH_pvalue)
#
#     # Append row to results
#     results <- rbind(results, row)
# }
#
# # Set column names for the results data frame
# colnames(results) <- c("Ancestry",
#                        "NSEG_EOPD", "NSEG_LOPD", "NSEG_pvalue",
#                        "KB_EOPD", "KB_LOPD", "KB_pvalue",
#                        "KBAVG_EOPD", "KBAVG_LOPD", "KBAVG_pvalue",
#                        "FROH_EOPD", "FROH_LOPD", "FROH_pvalue")
#
# # Save the results to a file
# fwrite(results, "Ttest_EOPD_vs_LOPD_ROH_parameters.txt")
#
# # Display the results
# results
# Out:
#   Ancestry   NSEG_EOPD NSEG_LOPD NSEG_pvalue           KB_EOPD
# 1      AAC     2.6 ± 4 1.8 ± 2.6       0.355  8245.1 ± 15765.5
# 2      AFR  7.3 ± 11.1 4.7 ± 3.3         0.3 25590.9 ± 59156.1
# 3       AJ     7 ± 4.1 7.4 ± 4.9       0.495 20847.5 ± 17799.5
# 4      AMR     6 ± 7.1 4.8 ± 5.1       0.144   19577 ± 40777.5
# 5      CAS     3.7 ± 6 2.8 ± 2.7        0.32    9192.6 ± 20794
# 6      EAS   2.6 ± 3.1 2.3 ± 2.5       0.205   5377.1 ± 8088.1
# 7      EUR     3 ± 3.4   3 ± 2.6       0.925    6727.8 ± 11991
# 8      MDE 20.8 ± 22.1  9.2 ± 13     0.00843   54008 ± 66361.2
# 9      SAS   5.3 ± 5.1 6.1 ± 9.8       0.672 11189.9 ± 12058.8
#             KB_LOPD KB_pvalue      KBAVG_EOPD      KBAVG_LOPD KBAVG_pvalue
# 1  5091.8 ± 16488.7     0.406 2240.1 ± 1401.7 1707.4 ± 1304.1        0.115
# 2    11624 ± 8641.2     0.293  2510.2 ± 806.4  2311.9 ± 820.7        0.304
# 3 22976.1 ± 27367.4     0.336  2854.1 ± 757.6  2901.1 ± 882.9          0.6
# ...

# %% [markdown]
# ### Regression: beta values

# %%
# %%R
#
# # List of ancestries to loop through
# ancestries <- c("AAC", "AFR", "AJ" ,"AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Initialize an empty data frame to store results
# results <- data.frame(NULL)
#
# # Loop through each ancestry
# for (ANC in ancestries) {
#     # Load ROH data with FROH (fractional ROH)
#     data <- fread(paste0(ANC, "_ROH_withFROH.hom.indiv"), header = TRUE)
#
#     # Recode cases and controls (exclude individuals with missing PHE)
#     dat <- data[data$PHE != -9, ]
#     dat$PHE <- dat$PHE - 1  # Recode PHE as 0 (controls) and 1 (cases)
#
#     # Load covariate data
#     cov <- fread(paste0(ANC, "_COVAR.txt"), header = TRUE)
#
#     # Merge ROH and covariate data by IID
#     merged <- merge(dat, cov, by = "IID")
#
#     # Impute missing age values with the mean (rounded to nearest integer)
#     merged_impute_age <- merged
#     merged_impute_age[is.na(merged_impute_age$age), ]$age <- round(mean(merged_impute_age$age, na.rm = TRUE), 0)
#
#     # Subset only PD cases and recode age of onset (AOO) as early (EOPD) and late onset (LOPD)
#     PD_cases <- subset(merged_impute_age, PHE == 1)
#     PD_cases$AOO_categoric <- ifelse(PD_cases$AOO < 45, 0, ifelse(PD_cases$AOO >= 45, 1, -9))
#     PD_cases <- PD_cases[PD_cases$AOO_categoric != -9, ]  # Exclude cases with missing AOO categoric values
#     PD_cases$AOO_categoric <- as.factor(PD_cases$AOO_categoric)  # Recode as factor
#
#     # Summarize mean, SD for each ROH parameter grouped by AOO category
#     PD_summary <- PD_cases %>%
#         group_by(AOO_categoric) %>%
#         summarise(
#             Number = n(),
#             NSEG_mean = mean(NSEG),
#             KB_mean = mean(KB),
#             KBAVG_mean = mean(KBAVG),
#             NSEG_sd = sd(NSEG),
#             KB_sd = sd(KB, na.rm = TRUE),
#             KBAVG_sd = sd(KBAVG, na.rm = TRUE),
#             FROH_mean = mean(FROH, na.rm = TRUE),
#             FROH_sd = sd(FROH, na.rm = TRUE)
#         )
#
#     # Perform logistic regressions for each ROH parameter
#     model1_Onset <- glm(AOO_categoric ~ NSEG + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = PD_cases, family = "binomial")
#     model2_Onset <- glm(AOO_categoric ~ KB + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = PD_cases, family = "binomial")
#     model3_Onset <- glm(AOO_categoric ~ KBAVG + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = PD_cases, family = "binomial")
#     model4_Onset <- glm(AOO_categoric ~ FROH + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = PD_cases, family = "binomial")
#
#     # Format results for each ROH parameter
#     EOPD_LOPD <- paste0(PD_summary$Number[1], " (", PD_summary$Number[2], ")")
#
#     # SROH (Sum of ROH lengths)
#     SROH_EOPD <- paste(round(PD_summary$KB_mean[1], 1), "±", round(PD_summary$KB_sd[1], 1))
#     SROH_LOPD <- paste(round(PD_summary$KB_mean[2], 1), "±", round(PD_summary$KB_sd[2], 1))
#     SROH_pvalue <- signif(summary(model2_Onset)$coef[2, 4], 3)
#
#     # AVROH (Average ROH length)
#     AVROH_EOPD <- paste(round(PD_summary$KBAVG_mean[1], 1), "±", round(PD_summary$KBAVG_sd[1], 1))
#     AVROH_LOPD <- paste(round(PD_summary$KBAVG_mean[2], 1), "±", round(PD_summary$KBAVG_sd[2], 1))
#     AVROH_pvalue <- signif(summary(model3_Onset)$coef[2, 4], 3)
#
#     # NROH (Number of ROH segments)
#     NROH_EOPD <- paste(round(PD_summary$NSEG_mean[1], 1), "±", round(PD_summary$NSEG_sd[1], 1))
#     NROH_LOPD <- paste(round(PD_summary$NSEG_mean[2], 1), "±", round(PD_summary$NSEG_sd[2], 1))
#     NROH_pvalue <- signif(summary(model1_Onset)$coef[2, 4], 3)
#
#     # FROH (Genomic inbreeding coefficient)
#     FROH_EOPD <- paste(round(PD_summary$FROH_mean[1], 4), "±", signif(PD_summary$FROH_sd[1], 2))
#     FROH_LOPD <- paste(round(PD_summary$FROH_mean[2], 4), "±", signif(PD_summary$FROH_sd[2], 2))
#     FROH_pvalue <- signif(summary(model4_Onset)$coef[2, 4], 3)
#
#     # Consolidate results into a row
#     row <- c(ANC, EOPD_LOPD, SROH_EOPD, SROH_LOPD, SROH_pvalue, AVROH_EOPD, AVROH_LOPD, AVROH_pvalue,
#              NROH_EOPD, NROH_LOPD, NROH_pvalue, FROH_EOPD, FROH_LOPD, FROH_pvalue)
#
#     # Append row to results
#     results <- rbind(results, row)
# }
#
# # Set column names for the results data frame
# colnames(results) <- c("Ancestries", "EOPD_LOPD", "SROH_EOPD", "SROH_LOPD", "SROH_pvalue", "AVROH_EOPD", "AVROH_LOPD", "AVROH_pvalue",
#                        "NROH_EOPD", "NROH_LOPD", "NROH_pvalue", "FROH_EOPD", "FROH_LOPD", "FROH_pvalue")
#
# # Save the results to a file
# fwrite(results, "Pvalues_regression_model_earlyVSlate.txt")
#
# # Display the results
# results
# Out:
#   Ancestries   EOPD_LOPD         SROH_EOPD         SROH_LOPD SROH_pvalue
# 1        AAC    21 (128)  8245.1 ± 15765.5  5091.8 ± 16488.7      0.0408
# 2        AFR    21 (137) 25590.9 ± 59156.1    11624 ± 8641.2      0.0746
# 3         AJ    83 (719) 20847.5 ± 17799.5 22976.1 ± 27367.4       0.903
# 4        AMR    91 (163)   19577 ± 40777.5 13160.7 ± 21016.2      0.0898
# 5        CAS     53 (57)    9192.6 ± 20794   5803.5 ± 6784.5       0.376
# 6        EAS   243 (455)   5377.1 ± 8088.1   4759.6 ± 6072.4       0.151
# 7        EUR 1042 (6400)    6727.8 ± 11991   6440.6 ± 8139.4      0.0552
# 8        MDE    31 (128)   54008 ± 66361.2 23094.8 ± 35773.6       0.825
# 9        SAS     22 (40) 11189.9 ± 12058.8 15590.6 ± 29727.7       0.848
#        AVROH_EOPD      AVROH_LOPD AVROH_pvalue   NROH_EOPD NROH_LOPD
# 1 2240.1 ± 1401.7 1707.4 ± 1304.1       0.0168     2.6 ± 4 1.8 ± 2.6
# 2  2510.2 ± 806.4  2311.9 ± 820.7        0.105  7.3 ± 11.1 4.7 ± 3.3
# ...

# %% [markdown]
# ## Suppl. Table 8 - Linear regression of ROH and PD AOO

# %% [markdown]
# ### Regression: beta values

# %%
# %%R
#
# # Define list of ancestries to loop through
# ancestries <- c("AAC", "AFR", "AJ" ,"AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Initialize data frame to store results
# results <- data.frame(NULL)
#
# # Loop over each ancestry
# for (ANC in 1:length(ancestries)) {
#
#     # Load ROH data with FROH for the current ancestry
#     data <- fread(paste0(ancestries[ANC], "_ROH_withFROH.hom.indiv"), header = TRUE)
#
#     # Recode cases and controls (exclude individuals with missing PHE)
#     dat <- data[data$PHE != -9, ]
#     dat$PHE <- dat$PHE - 1  # Recode PHE as 0 (controls) and 1 (cases)
#
#     # Load covariate data and merge with ROH data
#     cov <- fread(paste0(ancestries[ANC], "_COVAR.txt"), header = TRUE)
#     merged <- merge(dat, cov, by = "IID")
#
#     # Impute missing age values with the mean (rounded to nearest integer)
#     merged_impute_age <- merged
#     merged_impute_age[is.na(merged_impute_age$age), ]$age <- round(mean(merged_impute_age$age, na.rm = TRUE), 0)
#
#     # Subset only PD cases
#     PD_cases <- subset(merged_impute_age, PHE == 1)
#
#     # Calculate mean and SD for ROH parameters in PD cases
#     PD_tydy <- PD_cases %>%
#         summarise(
#             Number = n(),
#             NSEG_mean = mean(NSEG),
#             KB_mean = mean(KB),
#             KBAVG_mean = mean(KBAVG),
#             NSEG_sd = sd(NSEG),
#             KB_sd = sd(KB, na.rm = TRUE),
#             KBAVG_sd = sd(KBAVG, na.rm = TRUE),
#             FROH_mean = mean(FROH, na.rm = TRUE),
#             FROH_sd = sd(FROH, na.rm = TRUE)
#         )
#
#     # Perform linear regressions for each parameter
#     model1_Onset <- lm(AOO ~ NSEG + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = PD_cases)
#     model2_Onset <- lm(AOO ~ KB + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = PD_cases)
#     model3_Onset <- lm(AOO ~ KBAVG + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = PD_cases)
#     model4_Onset <- lm(AOO ~ FROH + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = PD_cases)
#
#     # Extract mean ± SD and linear regression results for each parameter
#     SROH_cases <- paste(round(PD_tydy$KB_mean[1], 1), round(PD_tydy$KB_sd[1], 1), sep = ' ± ')
#     SROH_beta <- signif(summary(model2_Onset)$coef[2, 1], 3)
#     SROH_pvalue <- signif(summary(model2_Onset)$coef[2, 4], 3)
#
#     AVROH_cases <- paste(round(PD_tydy$KBAVG_mean[1], 1), round(PD_tydy$KBAVG_sd[1], 1), sep = ' ± ')
#     AVROH_beta <- signif(summary(model3_Onset)$coef[2, 1], 3)
#     AVROH_pvalue <- signif(summary(model3_Onset)$coef[2, 4], 3)
#
#     NROH_cases <- paste(round(PD_tydy$NSEG_mean[1], 1), round(PD_tydy$NSEG_sd[1], 1), sep = ' ± ')
#     NROH_beta <- signif(summary(model1_Onset)$coef[2, 1], 3)
#     NROH_pvalue <- signif(summary(model1_Onset)$coef[2, 4], 3)
#
#     FROH_cases <- paste(round(PD_tydy$FROH_mean[1], 4), signif(PD_tydy$FROH_sd[1], 2), sep = ' ± ')
#     FROH_beta <- signif(summary(model4_Onset)$coef[2, 1], 3)
#     FROH_pvalue <- signif(summary(model4_Onset)$coef[2, 4], 3)
#
#     # Consolidate results into a row
#     row <- c(
#         ancestries[ANC],
#         SROH_cases, SROH_beta, SROH_pvalue,
#         AVROH_cases, AVROH_beta, AVROH_pvalue,
#         NROH_cases, NROH_beta, NROH_pvalue,
#         FROH_cases, FROH_beta, FROH_pvalue
#     )
#
#     # Append row to results
#     results <- rbind(results, row)
# }
#
# # Set column names for the results data frame
# colnames(results) <- c(
#     "Ancestry", "SROH_cases", "SROH_beta", "SROH_pvalue",
#     "AVROH_cases", "AVROH_beta", "AVROH_pvalue",
#     "NROH_cases", "NROH_beta", "NROH_pvalue",
#     "FROH_cases", "FROH_beta", "FROH_pvalue"
# )
#
# # Write results to file
# fwrite(results, "Pvalues_regression_model_AOO.txt")
#
# # Display results
# results
# Out:
#   Ancestry        SROH_cases SROH_beta SROH_pvalue     AVROH_cases AVROH_beta
# 1      AAC  6330.5 ± 15828.5  7.86e-06       0.793 1815.6 ± 1353.4  -0.000791
# 2      AFR  9820.3 ± 13817.2  1.55e-05       0.426  2252.6 ± 858.7  -0.000255
# 3       AJ   22595 ± 25823.3 -4.37e-06       0.631  2879.5 ± 870.1   0.000479
# 4      AMR 15162.8 ± 28418.6 -5.51e-05    0.000372 2302.8 ± 1235.4  -0.000878
# 5      CAS 13658.5 ± 34079.3  -2.8e-05       0.554    1885 ± 840.4    0.00023
# 6      EAS   5188.6 ± 7891.7 -2.14e-05       0.607  1735.7 ± 798.7   0.000303
# 7      EUR   6391.1 ± 8056.4 -2.04e-05      0.0274  1907.7 ± 730.3  -6.23e-05
# 8      MDE   26001.8 ± 41078    -6e-06       0.609  2048.5 ± 736.5   0.000768
# 9      SAS 12647.7 ± 21865.5 -7.17e-05       0.282  1995.5 ± 680.7   0.000447
#   AVROH_pvalue  NROH_cases NROH_beta NROH_pvalue      FROH_cases FROH_beta
# 1       0.0355   2.1 ± 3.1   -0.0131       0.939 0.0022 ± 0.0055      22.7
# ...

# %% [markdown]
# # Exploration of Homozygosity Parameters (without recessive genes)

# %% [markdown]
# ## Calculate FROH for all individuals

# %%
# %%R
#
# # List of ancestries to loop through
# ancestries <- c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Loop through each ancestry
# for (ANC in ancestries) {
#
#     # Read the individual-level ROH data file for the specific ancestry
#     data <- fread(paste0(ANC, "_ROH_nonRecessive.hom.indiv"), header = TRUE)
#
#     # Calculate FROH: total length of ROH segments (KB) divided by the length of the human autosomal genome (GRCh38)
#     data$FROH <- round(data$KB / 2886428, digits = 5)  # Autosomal genome length: 2,886,428 KB
#
#     # Write the updated data with FROH to a new file
#     fwrite(data, paste0(ANC, "_ROH_nonRecessive_withFROH.hom.indiv"))
# }

# %% [markdown]
# ## Generate COVAR file per ancestry

# %%
# %%R
#
# # List of ancestries to loop through
# ancestries <- c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Loop over each ancestry to process clinical and PCA data
# for (ANC in ancestries) {
#
#     # Load clinical data
#     clinical <- fread("master_key_release6_final.csv")
#     colnames(clinical)[2] <- "IID"  # Rename column 2 to 'IID' for consistency with PCA data
#
#     # Load PCA data for the specific ancestry
#     pca <- fread(paste0(ANC, "_release6.eigenvec"))
#
#     # Merge clinical data with PCA data by 'IID' (Individual ID)
#     merged <- merge(clinical, pca, by = "IID")
#
#     # Rename relevant columns for consistency and clarity
#     colnames(merged)[8] <- "SEX"  # Rename column 8 to 'SEX'
#     colnames(merged)[10] <- "AOO"  # Rename column 10 to 'AOO' (Age of Onset)
#
#     # Select relevant columns for the COVAR file
#     COVAR <- merged[, .(IID, SEX, age, PC1, PC2, PC3, PC4, PC5, PC6, PC7, PC8, PC9, PC10, AOO)]
#
#     # Write the COVAR file for each ancestry
#     fwrite(COVAR, paste0(ANC, "_COVAR.txt"))
# }

# %% [markdown]
# ## Suppl. Table 7 -  Cases vs. controls (excluding recessive genes)

# %% [markdown]
# ### T-test: mean values

# %%
# %%R
#
# # List of ancestries
# ancestries <- c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Initialize an empty data frame to store the results
# results <- data.frame(NULL)
#
# # Loop through each ancestry to perform t-tests
# for (ANC in 1:length(ancestries)) {
#     # Load the ROH data with FROH for the given ancestry
#     data <- fread(paste0(ancestries[ANC], "_ROH_withFROH.hom.indiv"), header = TRUE)
#
#     # Recode the cases and controls, where PHE == -9 is missing
#     dat <- data[data$PHE != -9, ]
#     dat$PHE <- dat$PHE - 1  # Adjust PHE: 1 for cases, 0 for controls
#
#     # Merge with covariates
#     cov <- fread(paste0(ancestries[ANC], "_COVAR.txt"), header = TRUE)
#     merged <- merge(dat, cov, by = "IID")
#
#     # Impute missing ages by replacing NA with the mean age
#     merged_impute_age <- merged
#     merged_impute_age[is.na(merged$age), ]$age <- round(mean(merged$age, na.rm = TRUE), 0)
#
#     # Filter only cases and classify them into Early-onset PD (AOO < 45) and Late-onset PD (AOO >= 45)
#     PD_cases <- subset(merged_impute_age, PHE == 1)
#     early_onset_PD <- subset(PD_cases, AOO < 45)
#     late_onset_PD <- subset(PD_cases, AOO >= 45)
#
#     # Calculate summary statistics (mean and SD) for Early-onset and Late-onset groups
#     early_tidy <- early_onset_PD %>%
#         summarise(Number = n(),
#                   NSEG_mean = mean(NSEG), NSEG_sd = sd(NSEG),
#                   KB_mean = mean(KB), KB_sd = sd(KB),
#                   KBAVG_mean = mean(KBAVG), KBAVG_sd = sd(KBAVG),
#                   FROH_mean = mean(FROH), FROH_sd = sd(FROH))
#
#     late_tidy <- late_onset_PD %>%
#         summarise(Number = n(),
#                   NSEG_mean = mean(NSEG), NSEG_sd = sd(NSEG),
#                   KB_mean = mean(KB), KB_sd = sd(KB),
#                   KBAVG_mean = mean(KBAVG), KBAVG_sd = sd(KBAVG),
#                   FROH_mean = mean(FROH), FROH_sd = sd(FROH))
#
#     # Perform t-tests between early-onset and late-onset PD groups for various parameters
#     t_test_NSEG <- t.test(NSEG ~ AOO >= 45, data = PD_cases)
#     t_test_KB <- t.test(KB ~ AOO >= 45, data = PD_cases)
#     t_test_KBAVG <- t.test(KBAVG ~ AOO >= 45, data = PD_cases)
#     t_test_FROH <- t.test(FROH ~ AOO >= 45, data = PD_cases)
#
#     # Prepare summary results for early and late-onset cases
#     # NSEG
#     NSEG_early <- paste(round(early_tidy$NSEG_mean, 1), "±", round(early_tidy$NSEG_sd, 1))
#     NSEG_late <- paste(round(late_tidy$NSEG_mean, 1), "±", round(late_tidy$NSEG_sd, 1))
#     NSEG_pvalue <- signif(t_test_NSEG$p.value, 3)
#
#     # SROH
#     KB_early <- paste(round(early_tidy$KB_mean, 1), "±", round(early_tidy$KB_sd, 1))
#     KB_late <- paste(round(late_tidy$KB_mean, 1), "±", round(late_tidy$KB_sd, 1))
#     KB_pvalue <- signif(t_test_KB$p.value, 3)
#
#     # AVROH
#     KBAVG_early <- paste(round(early_tidy$KBAVG_mean, 1), "±", round(early_tidy$KBAVG_sd, 1))
#     KBAVG_late <- paste(round(late_tidy$KBAVG_mean, 1), "±", round(late_tidy$KBAVG_sd, 1))
#     KBAVG_pvalue <- signif(t_test_KBAVG$p.value, 3)
#
#     # FROH
#     FROH_early <- paste(round(early_tidy$FROH_mean, 4), "±", signif(early_tidy$FROH_sd, 2))
#     FROH_late <- paste(round(late_tidy$FROH_mean, 4), "±", signif(late_tidy$FROH_sd, 2))
#     FROH_pvalue <- signif(t_test_FROH$p.value, 3)
#
#     # Consolidate the results for each ancestry
#     row <- c(ancestries[ANC],
#              NSEG_early, NSEG_late, NSEG_pvalue,
#              KB_early, KB_late, KB_pvalue,
#              KBAVG_early, KBAVG_late, KBAVG_pvalue,
#              FROH_early, FROH_late, FROH_pvalue)
#
#     # Append the row to the results data frame
#     results <- rbind(results, row)
# }
#
# # Set column names for the results
# colnames(results) <- c("Ancestry",
#                        "NSEG_Early", "NSEG_Late", "NSEG_pvalue",
#                        "SROH_Early", "SROH_Late", "SROH_pvalue",
#                        "AVROH_Early", "AVROH_Late", "AVROH_pvalue",
#                        "FROH_Early", "FROH_Late", "FROH_pvalue")
#
# # Write the results to a file
# fwrite(results, "TTest_EarlyVsLate_Onset.txt")
#
# # Display the results
# results
# Out:
#   Ancestry  NSEG_Early NSEG_Late NSEG_pvalue        SROH_Early
# 1      AAC     2.6 ± 4 1.8 ± 2.6       0.355  8245.1 ± 15765.5
# 2      AFR  7.3 ± 11.1 4.7 ± 3.3         0.3 25590.9 ± 59156.1
# 3       AJ     7 ± 4.1 7.4 ± 4.9       0.495 20847.5 ± 17799.5
# 4      AMR     6 ± 7.1 4.8 ± 5.1       0.144   19577 ± 40777.5
# 5      CAS     3.7 ± 6 2.8 ± 2.7        0.32    9192.6 ± 20794
# 6      EAS   2.6 ± 3.1 2.3 ± 2.5       0.205   5377.1 ± 8088.1
# 7      EUR     3 ± 3.4   3 ± 2.6       0.925    6727.8 ± 11991
# 8      MDE 20.8 ± 22.1  9.2 ± 13     0.00843   54008 ± 66361.2
# 9      SAS   5.3 ± 5.1 6.1 ± 9.8       0.672 11189.9 ± 12058.8
#           SROH_Late SROH_pvalue     AVROH_Early      AVROH_Late AVROH_pvalue
# 1  5091.8 ± 16488.7       0.406 2240.1 ± 1401.7 1707.4 ± 1304.1        0.115
# 2    11624 ± 8641.2       0.293  2510.2 ± 806.4  2311.9 ± 820.7        0.304
# 3 22976.1 ± 27367.4       0.336  2854.1 ± 757.6  2901.1 ± 882.9          0.6
# ...

# %% [markdown]
# ### Regression: beta values

# %%
# %%R
#
# # List of ancestries to analyze
# ancestries <- c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Initialize an empty data frame to store results
# results <- data.frame(NULL)
#
# # Loop through each ancestry in the list
# for (ANC in 1:length(ancestries)) {
#
#     # Load ROH data with FROH for non-recessive variants
#     data <- fread(paste0(ancestries[ANC], "_ROH_nonRecessive_withFROH.hom.indiv"), header = TRUE)
#
#     # Recode cases and controls (PHE == -9 indicates missing, recoded as 0 for controls and 1 for cases)
#     dat <- data[data$PHE != -9, ]
#     dat$PHE <- dat$PHE - 1  # Adjust PHE values for cases/controls (1 for cases, 0 for controls)
#
#     # Load covariate data and merge with the ROH data
#     cov <- fread(paste0(ancestries[ANC], "_COVAR.txt"), header = TRUE)
#     merged <- merge(dat, cov, by = "IID")
#
#     # Impute missing age values (replace NA with the rounded mean age)
#     merged_impute_age <- merged
#     merged_impute_age[is.na(merged_impute_age$age), ]$age <- round(mean(merged_impute_age$age, na.rm = TRUE), 0)
#
#     # Compute mean and SD for parameters grouped by case/control status
#     data_tydy <- merged_impute_age %>%
#         group_by(PHE) %>%
#         summarise(
#             NSEG_mean = mean(NSEG),
#             KB_mean = mean(KB),
#             KBAVG_mean = mean(KBAVG),
#             NSEG_sd = sd(NSEG),
#             KB_sd = sd(KB, na.rm = TRUE),
#             KBAVG_sd = sd(KBAVG, na.rm = TRUE),
#             FROH_mean = mean(FROH, na.rm = TRUE),
#             FROH_sd = sd(FROH, na.rm = TRUE)
#         )
#
#     # Run logistic regressions for each parameter
#     model1_imp <- glm(PHE ~ NSEG + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = merged_impute_age, family = "binomial")
#     model2_imp <- glm(PHE ~ KB + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = merged_impute_age, family = "binomial")
#     model3_imp <- glm(PHE ~ KBAVG + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = merged_impute_age, family = "binomial")
#     model4_imp <- glm(PHE ~ FROH + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = merged_impute_age, family = "binomial")
#
#     # Extract mean, SD, and p-values for each parameter
#     # SROH
#     SROH_cases <- paste(round(data_tydy$KB_mean[2], 1), round(data_tydy$KB_sd[2], 1), sep = ' ± ')
#     SROH_controls <- paste(round(data_tydy$KB_mean[1], 1), round(data_tydy$KB_sd[1], 1), sep = ' ± ')
#     SROH_pvalue <- signif(summary(model2_imp)$coef[2, 4], 3)
#
#     # AVROH
#     AVROH_cases <- paste(round(data_tydy$KBAVG_mean[2], 1), round(data_tydy$KBAVG_sd[2], 1), sep = ' ± ')
#     AVROH_controls <- paste(round(data_tydy$KBAVG_mean[1], 1), round(data_tydy$KBAVG_sd[1], 1), sep = ' ± ')
#     AVROH <- signif(summary(model3_imp)$coef[2, 4], 3)
#
#     # NROH
#     NROH_cases <- paste(round(data_tydy$NSEG_mean[2], 1), round(data_tydy$NSEG_sd[2], 1), sep = ' ± ')
#     NROH_controls <- paste(round(data_tydy$NSEG_mean[1], 1), round(data_tydy$NSEG_sd[1], 1), sep = ' ± ')
#     NROH <- signif(summary(model1_imp)$coef[2, 4], 3)
#
#     # FROH
#     FROH_cases <- paste(round(data_tydy$FROH_mean[2], 4), signif(data_tydy$FROH_sd[2], 1), sep = ' ± ')
#     FROH_controls <- paste(round(data_tydy$FROH_mean[1], 4), signif(data_tydy$FROH_sd[1], 1), sep = ' ± ')
#     FROH <- signif(summary(model4_imp)$coef[2, 4], 3)
#
#     # Consolidate results for this ancestry into a row
#     row <- c(
#         ancestries[ANC],
#         SROH_cases, SROH_controls, SROH_pvalue,
#         AVROH_cases, AVROH_controls, AVROH,
#         NROH_cases, NROH_controls, NROH,
#         FROH_cases, FROH_controls, FROH
#     )
#
#     # Add the row to the results data frame
#     results <- rbind(results, row)
# }
#
# # Set column names for the results
# colnames(results) <- c(
#     "Ancestries", "SROH_cases", "SROH_controls", "SROH_pvalue",
#     "AVROH_cases", "AVROH_controls", "AVROH_pvalue",
#     "NROH_cases", "NROH_controls", "NROH_pvalue",
#     "FROH_cases", "FROH_controls", "FROH_pvalue"
# )
#
# # Write the results to a file
# fwrite(results, "Pvalues_regression_model_casesVScontrols_nonRecessive.txt")
#
# # Display the results
# results
# Out:
#   Ancestries        SROH_cases     SROH_controls SROH_pvalue     AVROH_cases
# 1        AAC  6330.5 ± 15828.5  4373.8 ± 10741.9      0.0337 1815.6 ± 1353.4
# 2        AFR  9814.6 ± 13786.7  8157.1 ± 12021.8      0.0389  2252.7 ± 858.6
# 3         AJ 22579.8 ± 25805.7 21493.2 ± 17540.3       0.448  2878.5 ± 869.3
# 4        AMR 15143.2 ± 28321.4 13186.3 ± 15927.9       0.347 2302.8 ± 1236.3
# 5        CAS 13651.4 ± 34036.4 19711.7 ± 40945.7       0.925  1885.2 ± 840.7
# 6        EAS   5187.5 ± 7880.2   7133.2 ± 9449.7      0.0661  1735.7 ± 798.8
# 7        EUR   6389.6 ± 8048.7    7051 ± 10925.2    4.51e-07  1907.8 ± 730.3
# 8        MDE 25964.3 ± 41064.9 11143.3 ± 13622.3      0.0544    2049.4 ± 737
# 9        SAS 12647.6 ± 21865.5 34198.7 ± 57886.9    0.000544  1995.5 ± 680.6
#    AVROH_controls AVROH_pvalue  NROH_cases NROH_controls NROH_pvalue
# 1   1580.9 ± 1158      0.00469   2.1 ± 3.1       1.7 ± 3      0.0774
# ...

# %% [markdown]
# ## Suppl. Table 10 - Early- and late- onset cases vs. controls (without recessive genes)

# %% [markdown]
# ### T-test: mean values

# %%
# %%R
#
# # List of ancestries to analyze
# ancestries <- c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Initialize an empty data frame to store results
# results <- data.frame(NULL)
#
# # Loop over each ancestry for analysis
# for(ANC in 1:length(ancestries)) {
#
#     # Load the ROH data with FROH for the given ancestry
#     data <- fread(paste0(ancestries[ANC], "_ROH_nonRecessive_withFROH.hom.indiv"), header = TRUE)
#
#     # Filter out rows where PHE is missing (-9), and recode cases (PHE == 1) and controls (PHE == 0)
#     dat <- data[data$PHE != -9, ]
#     dat$PHE <- dat$PHE - 1  # 1 for cases, 0 for controls
#
#     # Load covariates (e.g., sex, age, principal components)
#     cov <- fread(paste0(ancestries[ANC], "_COVAR.txt"), header = TRUE)
#
#     # Merge ROH data with covariates
#     merged <- merge(dat, cov, by = "IID")
#
#     # Impute missing age values by replacing NAs with the mean age
#     merged_impute_age <- merged
#     merged_impute_age[is.na(merged$age), ]$age <- round(mean(merged$age, na.rm = TRUE), 0)
#
#     # Split data into two subsets: early-onset (AOO < 45) and late-onset (AOO >= 45) cases
#     eopd <- subset(merged_impute_age, PHE == 0 | AOO < 45)  # EOPD and controls
#     lopd <- subset(merged_impute_age, PHE == 0 | AOO >= 45)  # LOPD and controls
#
#     # Generate mean and SD for ROH parameters for each group (early-onset and late-onset)
#     eopd_summary <- eopd %>%
#         group_by(PHE) %>%
#         summarise(
#             NSEG_mean = mean(NSEG), NSEG_sd = sd(NSEG),
#             KB_mean = mean(KB), KB_sd = sd(KB),
#             KBAVG_mean = mean(KBAVG), KBAVG_sd = sd(KBAVG),
#             FROH_mean = mean(FROH), FROH_sd = sd(FROH)
#         )
#
#     lopd_summary <- lopd %>%
#         group_by(PHE) %>%
#         summarise(
#             NSEG_mean = mean(NSEG), NSEG_sd = sd(NSEG),
#             KB_mean = mean(KB), KB_sd = sd(KB),
#             KBAVG_mean = mean(KBAVG), KBAVG_sd = sd(KBAVG),
#             FROH_mean = mean(FROH), FROH_sd = sd(FROH)
#         )
#
#     # Perform t-tests for each parameter (EOPD vs Controls)
#     t_test_nseg_eopd <- t.test(NSEG ~ PHE, data = eopd)
#     t_test_kb_eopd <- t.test(KB ~ PHE, data = eopd)
#     t_test_kbavg_eopd <- t.test(KBAVG ~ PHE, data = eopd)
#     t_test_froh_eopd <- t.test(FROH ~ PHE, data = eopd)
#
#     # Perform t-tests for each parameter (LOPD vs Controls)
#     t_test_nseg_lopd <- t.test(NSEG ~ PHE, data = lopd)
#     t_test_kb_lopd <- t.test(KB ~ PHE, data = lopd)
#     t_test_kbavg_lopd <- t.test(KBAVG ~ PHE, data = lopd)
#     t_test_froh_lopd <- t.test(FROH ~ PHE, data = lopd)
#
#     # Extract p-values for EOPD vs Controls
#     NSEG_pvalue_eopd <- signif(t_test_nseg_eopd$p.value, 3)
#     KB_pvalue_eopd <- signif(t_test_kb_eopd$p.value, 3)
#     KBAVG_pvalue_eopd <- signif(t_test_kbavg_eopd$p.value, 3)
#     FROH_pvalue_eopd <- signif(t_test_froh_eopd$p.value, 3)
#
#     # Extract p-values for LOPD vs Controls
#     NSEG_pvalue_lopd <- signif(t_test_nseg_lopd$p.value, 3)
#     KB_pvalue_lopd <- signif(t_test_kb_lopd$p.value, 3)
#     KBAVG_pvalue_lopd <- signif(t_test_kbavg_lopd$p.value, 3)
#     FROH_pvalue_lopd <- signif(t_test_froh_lopd$p.value, 3)
#
#     # Format results (mean ± SD) for EOPD vs Controls
#     NSEG_eopd <- paste(round(eopd_summary$NSEG_mean[2], 1), "±", round(eopd_summary$NSEG_sd[2], 1))
#     NSEG_controls_eopd <- paste(round(eopd_summary$NSEG_mean[1], 1), "±", round(eopd_summary$NSEG_sd[1], 1))
#
#     KB_eopd <- paste(round(eopd_summary$KB_mean[2], 1), "±", round(eopd_summary$KB_sd[2], 1))
#     KB_controls_eopd <- paste(round(eopd_summary$KB_mean[1], 1), "±", round(eopd_summary$KB_sd[1], 1))
#
#     KBAVG_eopd <- paste(round(eopd_summary$KBAVG_mean[2], 1), "±", round(eopd_summary$KBAVG_sd[2], 1))
#     KBAVG_controls_eopd <- paste(round(eopd_summary$KBAVG_mean[1], 1), "±", round(eopd_summary$KBAVG_sd[1], 1))
#
#     FROH_eopd <- paste(round(eopd_summary$FROH_mean[2], 4), "±", round(eopd_summary$FROH_sd[2], 4))
#     FROH_controls_eopd <- paste(round(eopd_summary$FROH_mean[1], 4), "±", round(eopd_summary$FROH_sd[1], 4))
#
#     # Format results (mean ± SD) for LOPD vs Controls
#     NSEG_lopd <- paste(round(lopd_summary$NSEG_mean[2], 1), "±", round(lopd_summary$NSEG_sd[2], 1))
#     NSEG_controls_lopd <- paste(round(lopd_summary$NSEG_mean[1], 1), "±", round(lopd_summary$NSEG_sd[1], 1))
#
#     KB_lopd <- paste(round(lopd_summary$KB_mean[2], 1), "±", round(lopd_summary$KB_sd[2], 1))
#     KB_controls_lopd <- paste(round(lopd_summary$KB_mean[1], 1), "±", round(lopd_summary$KB_sd[1], 1))
#
#     KBAVG_lopd <- paste(round(lopd_summary$KBAVG_mean[2], 1), "±", round(lopd_summary$KBAVG_sd[2], 1))
#     KBAVG_controls_lopd <- paste(round(lopd_summary$KBAVG_mean[1], 1), "±", round(lopd_summary$KBAVG_sd[1], 1))
#
#     FROH_lopd <- paste(round(lopd_summary$FROH_mean[2], 4), "±", round(lopd_summary$FROH_sd[2], 4))
#     FROH_controls_lopd <- paste(round(lopd_summary$FROH_mean[1], 4), "±", round(lopd_summary$FROH_sd[1], 4))
#
#     # Consolidate results into a row
#     row <- c(ancestries[ANC],
#              NSEG_eopd, NSEG_controls_eopd, NSEG_pvalue_eopd,
#              KB_eopd, KB_controls_eopd, KB_pvalue_eopd,
#              KBAVG_eopd, KBAVG_controls_eopd, KBAVG_pvalue_eopd,
#              FROH_eopd, FROH_controls_eopd, FROH_pvalue_eopd,
#              NSEG_lopd, NSEG_controls_lopd, NSEG_pvalue_lopd,
#              KB_lopd, KB_controls_lopd, KB_pvalue_lopd,
#              KBAVG_lopd, KBAVG_controls_lopd, KBAVG_pvalue_lopd,
#              FROH_lopd, FROH_controls_lopd, FROH_pvalue_lopd)
#
#     # Add row to results
#     results <- rbind(results, row)
# }
#
# # Define column names for the results data frame
# colnames(results) <- c("Ancestry",
#                        "NSEG_EOPD", "NSEG_Controls_EOPD", "NSEG_pvalue_EOPD",
#                        "KB_EOPD", "KB_Controls_EOPD", "KB_pvalue_EOPD",
#                        "KBAVG_EOPD", "KBAVG_Controls_EOPD", "KBAVG_pvalue_EOPD",
#                        "FROH_EOPD", "FROH_Controls_EOPD", "FROH_pvalue_EOPD",
#                        "NSEG_LOPD", "NSEG_Controls_LOPD", "NSEG_pvalue_LOPD",
#                        "KB_LOPD", "KB_Controls_LOPD", "KB_pvalue_LOPD",
#                        "KBAVG_LOPD", "KBAVG_Controls_LOPD", "KBAVG_pvalue_LOPD",
#                        "FROH_LOPD", "FROH_Controls_LOPD", "FROH_pvalue_LOPD")
#
# # Save the results to a file
# fwrite(results, "Ttest_EOPD_LOPD_vs_Controls_ROH.txt")
#
# # Display the results
# results
# Out:
#   Ancestry   NSEG_EOPD NSEG_Controls_EOPD NSEG_pvalue_EOPD           KB_EOPD
# 1      AAC     2.6 ± 4            1.7 ± 3            0.332  8245.1 ± 15765.5
# 2      AFR  7.3 ± 11.1          3.3 ± 3.9            0.109 25525.3 ± 58858.6
# 3       AJ     7 ± 4.1          7.2 ± 3.9            0.685 20847.5 ± 17799.5
# 4      AMR     6 ± 7.1          4.6 ± 3.6           0.0843 19517.8 ± 40595.9
# 5      CAS     3.7 ± 6         6.8 ± 11.5          0.00422    9192.6 ± 20794
# 6      EAS   2.6 ± 3.1            3.4 ± 4         0.000786   5370.4 ± 8016.6
# 7      EUR     3 ± 3.4          3.2 ± 3.2            0.197    6722.8 ± 11972
# 8      MDE 20.7 ± 22.1          4.6 ± 4.3         0.000374 53929.1 ± 66341.1
# 9      SAS   5.3 ± 5.1        11.8 ± 17.9          0.00022 11189.9 ± 12058.8
#    KB_Controls_EOPD KB_pvalue_EOPD      KBAVG_EOPD KBAVG_Controls_EOPD
# 1  4373.8 ± 10741.9          0.276 2240.1 ± 1401.7       1580.9 ± 1158
# ...

# %% [markdown]
# ### Regression: beta values

# %%
# %%R
#
# # List of ancestries to analyze
# ancestries <- c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Initialize an empty data frame to store results
# results <- data.frame(NULL)
#
# # Loop over each ancestry for analysis
# for(ANC in 1:length(ancestries)) {
#
#     # Load the ROH data with FROH for the given ancestry
#     data <- fread(paste0(ancestries[ANC], "_ROH_nonRecessive_withFROH.hom.indiv"), header = TRUE)
#
#     # Filter out rows where PHE is missing (-9), and recode cases (PHE == 1) and controls (PHE == 0)
#     dat <- data[data$PHE != -9, ]
#     dat$PHE <- dat$PHE - 1  # 1 for cases, 0 for controls
#
#     # Load covariates (e.g., sex, age, principal components)
#     cov <- fread(paste0(ancestries[ANC], "_COVAR.txt"), header = TRUE)
#
#     # Merge ROH data with covariates
#     merged <- merge(dat, cov, by = "IID")
#
#     # Impute missing age values by replacing NAs with the mean age
#     merged_impute_age <- merged
#     merged_impute_age[is.na(merged$age), ]$age <- round(mean(merged$age, na.rm = TRUE), 0)
#
#     # Split data into two subsets: early-onset (AOO < 45) and late-onset (AOO >= 45) cases
#     early <- subset(merged_impute_age, PHE == 0 | AOO < 45)
#     late <- subset(merged_impute_age, PHE == 0 | AOO >= 45)
#
#     # Generate mean and SD for ROH parameters for each group (early-onset and late-onset)
#     early_tydy <- early %>%
#         group_by(PHE) %>%
#         summarise(Number = n(), NSEG_mean = mean(NSEG), KB_mean = mean(KB), KBAVG_mean = mean(KBAVG),
#                   NSEG_sd = sd(NSEG), KB_sd = sd(KB, na.rm = TRUE), KBAVG_sd = sd(KBAVG, na.rm = TRUE),
#                   FROH_mean = mean(FROH, na.rm = TRUE), FROH_sd = sd(FROH, na.rm = TRUE))
#
#     late_tydy <- late %>%
#         group_by(PHE) %>%
#         summarise(Number = n(), NSEG_mean = mean(NSEG), KB_mean = mean(KB), KBAVG_mean = mean(KBAVG),
#                   NSEG_sd = sd(NSEG), KB_sd = sd(KB, na.rm = TRUE), KBAVG_sd = sd(KBAVG, na.rm = TRUE),
#                   FROH_mean = mean(FROH, na.rm = TRUE), FROH_sd = sd(FROH, na.rm = TRUE))
#
#     # Perform logistic regressions for each parameter (SROH, AVROH, NROH, FROH)
#     model1_early <- glm(PHE ~ NSEG + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = early, family = "binomial")
#     model1_late <- glm(PHE ~ NSEG + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = late, family = "binomial")
#
#     model2_early <- glm(PHE ~ KB + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = early, family = "binomial")
#     model2_late <- glm(PHE ~ KB + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = late, family = "binomial")
#
#     model3_early <- glm(PHE ~ KBAVG + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = early, family = "binomial")
#     model3_late <- glm(PHE ~ KBAVG + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = late, family = "binomial")
#
#     model4_early <- glm(PHE ~ FROH + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = early, family = "binomial")
#     model4_late <- glm(PHE ~ FROH + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = late, family = "binomial")
#
#     # Calculate the number of early-onset and late-onset cases and controls
#     earlycases_controls <- paste0(early_tydy$Number[2], " (", early_tydy$Number[1], ")")
#     latecases_controls <- paste0(late_tydy$Number[2], " (", late_tydy$Number[1], ")")
#
#     # Format results for mean, SD, and p-values for each parameter
#     # SROH
#     SROH_case_early <- paste(round(early_tydy$KB_mean[2], 1), " ± ", round(early_tydy$KB_sd[2], 1))
#     SROH_case_late <- paste(round(late_tydy$KB_mean[2], 1), " ± ", round(late_tydy$KB_sd[2], 1))
#     SROH_controls <- paste(round(late_tydy$KB_mean[1], 1), " ± ", round(late_tydy$KB_sd[1], 1))
#     SROH_early <- signif(summary(model2_early)$coef[2, 4], 3)
#     SROH_late <- signif(summary(model2_late)$coef[2, 4], 3)
#
#     # AVROH
#     AVROH_case_early <- paste(round(early_tydy$KBAVG_mean[2], 1), " ± ", round(early_tydy$KBAVG_sd[2], 1))
#     AVROH_case_late <- paste(round(late_tydy$KBAVG_mean[2], 1), " ± ", round(late_tydy$KBAVG_sd[2], 1))
#     AVROH_controls <- paste(round(late_tydy$KBAVG_mean[1], 1), " ± ", round(late_tydy$KBAVG_sd[1], 1))
#     AVROH_early <- signif(summary(model3_early)$coef[2, 4], 3)
#     AVROH_late <- signif(summary(model3_late)$coef[2, 4], 3)
#
#     # NROH
#     NROH_case_early <- paste(round(early_tydy$NSEG_mean[2], 1), " ± ", round(early_tydy$NSEG_sd[2], 1))
#     NROH_case_late <- paste(round(late_tydy$NSEG_mean[2], 1), " ± ", round(late_tydy$NSEG_sd[2], 1))
#     NROH_controls <- paste(round(late_tydy$NSEG_mean[1], 1), " ± ", round(late_tydy$NSEG_sd[1], 1))
#     NROH_early <- signif(summary(model1_early)$coef[2, 4], 3)
#     NROH_late <- signif(summary(model1_late)$coef[2, 4], 3)
#
#     # FROH
#     FROH_case_early <- paste(round(early_tydy$FROH_mean[2], 4), " ± ", signif(early_tydy$FROH_sd[2], 2))
#     FROH_case_late <- paste(round(late_tydy$FROH_mean[2], 4), " ± ", signif(late_tydy$FROH_sd[2], 2))
#     FROH_controls <- paste(round(late_tydy$FROH_mean[1], 4), " ± ", signif(late_tydy$FROH_sd[1], 2))
#     FROH_early <- signif(summary(model4_early)$coef[2, 4], 3)
#     FROH_late <- signif(summary(model4_late)$coef[2, 4], 3)
#
#     # Consolidate results for early and late-onset PD cases
#     row1 <- c(ancestries[ANC], "EOPD", earlycases_controls,
#               SROH_case_early, SROH_controls, SROH_early,
#               AVROH_case_early, AVROH_controls, AVROH_early,
#               NROH_case_early, NROH_controls, NROH_early,
#               FROH_case_early, FROH_controls, FROH_early)
#
#     row2 <- c(ancestries[ANC], "LOPD", latecases_controls,
#               SROH_case_late, SROH_controls, SROH_late,
#               AVROH_case_late, AVROH_controls, AVROH_late,
#               NROH_case_late, NROH_controls, NROH_late,
#               FROH_case_late, FROH_controls, FROH_late)
#
#     # Append the results for each ancestry
#     row <- rbind(row1, row2)
#     results <- rbind(results, row)
# }
#
# # Define column names for the results data frame
# colnames(results) <- c("Ancestry", "Onset", "Cases_Controls",
#                        "SROH_case", "SROH_controls", "SROH_pvalue",
#                        "AVROH_case", "AVROH_controls", "AVROH_pvalue",
#                        "NROH_case", "NROH_controls", "NROH_pvalue",
#                        "FROH_case", "FROH_controls", "FROH_pvalue")
#
# # Save the results to a file
# fwrite(results, "Pvalues_regression_model_Subset_casesVScontrols_nonRecessive.txt")
#
# # Display the results
# results
# Out:
#       Ancestry Onset Cases_Controls           SROH_case       SROH_controls
# row1       AAC  EOPD       21 (804)  8245.1  ±  15765.5  4373.8  ±  10741.9
# row2       AAC  LOPD      128 (804)  5091.8  ±  16488.7  4373.8  ±  10741.9
# row11      AFR  EOPD      21 (1631) 25525.3  ±  58858.6  8157.1  ±  12021.8
# row21      AFR  LOPD     137 (1631)  11611.8  ±  8644.8  8157.1  ±  12021.8
# row12       AJ  EOPD       83 (458) 20847.5  ±  17799.5 21493.2  ±  17540.3
# row22       AJ  LOPD      719 (458) 22962.5  ±  27350.7 21493.2  ±  17540.3
# row13      AMR  EOPD       91 (139) 19517.8  ±  40595.9 13186.3  ±  15927.9
# row23      AMR  LOPD      163 (139) 13149.9  ±  20924.2 13186.3  ±  15927.9
# row14      CAS  EOPD       53 (267)    9192.6  ±  20794 19711.7  ±  40945.7
# row24      CAS  LOPD       57 (267)   5803.5  ±  6784.5 19711.7  ±  40945.7
# row15      EAS  EOPD     243 (2302)   5370.4  ±  8016.6   7133.2  ±  9449.7
# ...

# %% [markdown]
# ## Suppl. Table 11 -  Early- vs. late- onset (excluding recessive genes)

# %% [markdown]
# ### T-test: mean values

# %%
# %%R
#
# # Define the ancestries to be analyzed
# ancestries <- c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
# results <- data.frame(NULL)  # Initialize an empty dataframe to store results
#
# # Loop through each ancestry to perform analysis
# for(ANC in 1:length(ancestries)) {
#
#     # Load the ROH data with FROH values for the current ancestry
#     data <- fread(paste0(ancestries[ANC], "_ROH_nonRecessive_withFROH.hom.indiv"), header = TRUE)
#
#     # Recode cases (PHE == 1) and controls (PHE == 0), and filter out missing values
#     dat <- data[data$PHE != -9 , ]
#     dat$PHE <- dat$PHE - 1  # Recode PHE so that cases = 1 and controls = 0
#
#     # Load covariates and merge with ROH data
#     cov <- fread(paste0(ancestries[ANC], "_COVAR.txt"), header = TRUE)
#     merged <- merge(dat, cov, by = "IID")
#
#     # Impute missing age values using the mean age
#     merged_impute_age <- merged
#     merged_impute_age[is.na(merged$age),]$age <- round(mean(merged$age, na.rm = TRUE), 0)
#
#     # Subset cases and recode age of onset (AOO) into EOPD (< 45 years) and LOPD (>= 45 years)
#     PD_cases <- subset(merged_impute_age, PHE == 1)
#     PD_cases$AOO_categoric <- ifelse(PD_cases$AOO < 45, 0, ifelse(PD_cases$AOO >= 45, 1, -9))
#     PD_cases <- PD_cases[PD_cases$AOO_categoric != -9 , ]  # Remove invalid AOO values
#     PD_cases$AOO_categoric <- as.factor(PD_cases$AOO_categoric)  # Convert AOO to factor
#
#     # Compute mean and standard deviation for each parameter (NSEG, KB, KBAVG, FROH)
#     PD_tydy <- PD_cases  %>%
#         group_by(AOO_categoric) %>%
#         summarise(Number = n(),
#                   NSEG_mean = mean(NSEG), KB_mean = mean(KB), KBAVG_mean = mean(KBAVG),
#                   NSEG_sd = sd(NSEG), KB_sd = sd(KB, na.rm = TRUE), KBAVG_sd = sd(KBAVG, na.rm = TRUE),
#                   FROH_mean = mean(FROH, na.rm = TRUE), FROH_sd = sd(FROH, na.rm = TRUE))
#
#     # Print summary statistics for the current ancestry
#     print(paste("Ancestry:", ancestries[ANC]))
#     print(PD_tydy)
#
#     # Perform t-tests for EOPD vs LOPD on the parameters
#     t_test_nseg <- t.test(NSEG ~ AOO_categoric, data = PD_cases)
#     t_test_kb <- t.test(KB ~ AOO_categoric, data = PD_cases)
#     t_test_kbavg <- t.test(KBAVG ~ AOO_categoric, data = PD_cases)
#     t_test_froh <- t.test(FROH ~ AOO_categoric, data = PD_cases)
#
#     # Extract p-values for each parameter
#     NSEG_pvalue <- signif(t_test_nseg$p.value, 3)
#     KB_pvalue <- signif(t_test_kb$p.value, 3)
#     KBAVG_pvalue <- signif(t_test_kbavg$p.value, 3)
#     FROH_pvalue <- signif(t_test_froh$p.value, 3)
#
#     # Format results for NSEG, KB, KBAVG, and FROH (mean ± SD) for both EOPD and LOPD
#     NSEG_eopd <- paste(round(PD_tydy$NSEG_mean[1], 1), "±", round(PD_tydy$NSEG_sd[1], 1))
#     NSEG_lopd <- paste(round(PD_tydy$NSEG_mean[2], 1), "±", round(PD_tydy$NSEG_sd[2], 1))
#
#     KB_eopd <- paste(round(PD_tydy$KB_mean[1], 1), "±", round(PD_tydy$KB_sd[1], 1))
#     KB_lopd <- paste(round(PD_tydy$KB_mean[2], 1), "±", round(PD_tydy$KB_sd[2], 1))
#
#     KBAVG_eopd <- paste(round(PD_tydy$KBAVG_mean[1], 1), "±", round(PD_tydy$KBAVG_sd[1], 1))
#     KBAVG_lopd <- paste(round(PD_tydy$KBAVG_mean[2], 1), "±", round(PD_tydy$KBAVG_sd[2], 1))
#
#     FROH_eopd <- paste(round(PD_tydy$FROH_mean[1], 4), "±", round(PD_tydy$FROH_sd[1], 4))
#     FROH_lopd <- paste(round(PD_tydy$FROH_mean[2], 4), "±", round(PD_tydy$FROH_sd[2], 4))
#
#     # Consolidate the results for each ancestry
#     row <- c(ancestries[ANC],
#              NSEG_eopd, NSEG_lopd, NSEG_pvalue,
#              KB_eopd, KB_lopd, KB_pvalue,
#              KBAVG_eopd, KBAVG_lopd, KBAVG_pvalue,
#              FROH_eopd, FROH_lopd, FROH_pvalue)
#
#     # Append the results to the results dataframe
#     results <- rbind(results, row)
# }
#
# # Define column names for the results data frame
# colnames(results) <- c("Ancestry",
#                        "NSEG_EOPD", "NSEG_LOPD", "NSEG_pvalue",
#                        "KB_EOPD", "KB_LOPD", "KB_pvalue",
#                        "KBAVG_EOPD", "KBAVG_LOPD", "KBAVG_pvalue",
#                        "FROH_EOPD", "FROH_LOPD", "FROH_pvalue")
#
# # Save the results to a file
# fwrite(results, "Ttest_EOPD_vs_LOPD_ROH.txt")
#
# # Display the results
# results
# Out:
# [1] "Ancestry: AAC"
# # A tibble: 2 × 10
#   AOO_categoric Number NSEG_mean KB_mean KBAVG_mean NSEG_sd  KB_sd KBAVG_sd
#   <fct>          <int>     <dbl>   <dbl>      <dbl>   <dbl>  <dbl>    <dbl>
# 1 0                 21      2.62   8245.      2240.    4.04 15765.    1402.
# 2 1                128      1.76   5092.      1707.    2.64 16489.    1304.
# # ℹ 2 more variables: FROH_mean <dbl>, FROH_sd <dbl>
# [1] "Ancestry: AFR"
# # A tibble: 2 × 10
#   AOO_categoric Number NSEG_mean KB_mean KBAVG_mean NSEG_sd  KB_sd KBAVG_sd
#   <fct>          <int>     <dbl>   <dbl>      <dbl>   <dbl>  <dbl>    <dbl>
# 1 0                 21      7.33  25525.      2509.   11.1  58859.     802.
# 2 1                137      4.74  11612.      2312.    3.28  8645.     821.
# # ℹ 2 more variables: FROH_mean <dbl>, FROH_sd <dbl>
# [1] "Ancestry: AJ"
# # A tibble: 2 × 10
#   AOO_categoric Number NSEG_mean KB_mean KBAVG_mean NSEG_sd  KB_sd KBAVG_sd
# ...

# %% [markdown]
# ### Regression: beta values

# %%
# %%R
#
# # Define the ancestries to be analyzed
# ancestries <- c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
# results <- data.frame(NULL)  # Initialize an empty dataframe to store results
#
# # Loop through each ancestry to perform analysis
# for(ANC in 1:length(ancestries)) {
#
#     # Load the ROH data with FROH values for the current ancestry
#     data <- fread(paste0(ancestries[ANC], "_ROH_nonRecessive_withFROH.hom.indiv"), header = TRUE)
#
#     # Recode cases (PHE == 1) and controls (PHE == 0), and filter out missing values
#     dat <- data[data$PHE != -9 , ]
#     dat$PHE <- dat$PHE - 1  # Recode PHE so that cases = 1 and controls = 0
#
#     # Load covariates and merge with ROH data
#     cov <- fread(paste0(ancestries[ANC], "_COVAR.txt"), header = TRUE)
#     merged <- merge(dat, cov, by = "IID")
#
#     # Impute missing age values using the mean age
#     merged_impute_age <- merged
#     merged_impute_age[is.na(merged$age),]$age <- round(mean(merged$age, na.rm = TRUE), 0)
#
#     # Subset cases and recode age of onset (AOO) into EOPD (< 45 years) and LOPD (>= 45 years)
#     PD_cases <- subset(merged_impute_age, PHE == 1)
#     PD_cases$AOO_categoric <- ifelse(PD_cases$AOO < 45, 0, ifelse(PD_cases$AOO >= 45, 1, -9))
#     PD_cases <- PD_cases[PD_cases$AOO_categoric != -9 , ]  # Remove invalid AOO values
#     PD_cases$AOO_categoric <- as.factor(PD_cases$AOO_categoric)  # Convert AOO to factor
#
#     # Compute mean and standard deviation for each parameter (NSEG, KB, KBAVG, FROH)
#     PD_tydy <- PD_cases  %>%
#         group_by(AOO_categoric) %>%
#         summarise(Number = n(),
#                   NSEG_mean = mean(NSEG), KB_mean = mean(KB), KBAVG_mean = mean(KBAVG),
#                   NSEG_sd = sd(NSEG), KB_sd = sd(KB, na.rm = TRUE), KBAVG_sd = sd(KBAVG, na.rm = TRUE),
#                   FROH_mean = mean(FROH, na.rm = TRUE), FROH_sd = sd(FROH, na.rm = TRUE))
#
#     # Perform logistic regressions for each ROH parameter (SROH, AVROH, NROH, FROH)
#     model1_Onset <- glm(AOO_categoric ~ NSEG + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = PD_cases, family = "binomial")
#     model2_Onset <- glm(AOO_categoric ~ KB + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = PD_cases, family = "binomial")
#     model3_Onset <- glm(AOO_categoric ~ KBAVG + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = PD_cases, family = "binomial")
#     model4_Onset <- glm(AOO_categoric ~ FROH + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = PD_cases, family = "binomial")
#
#     # Format the results for the table
#     EOPD_LOPD <- paste0(PD_tydy$Number[1], " (", PD_tydy$Number[2], ")")  # Number of EOPD and LOPD cases
#
#     # SROH results
#     SROH_EOPD <- paste(round(PD_tydy$KB_mean[1], 1), " ± ", round(PD_tydy$KB_sd[1], 1), sep = '')
#     SROH_LOPD <- paste(round(PD_tydy$KB_mean[2], 1), " ± ", round(PD_tydy$KB_sd[2], 1), sep = '')
#     SROH_pvalue <- signif(summary(model2_Onset)$coef[2, 4], 3)
#
#     # AVROH results
#     AVROH_EOPD <- paste(round(PD_tydy$KBAVG_mean[1], 1), " ± ", round(PD_tydy$KBAVG_sd[1], 1), sep = '')
#     AVROH_LOPD <- paste(round(PD_tydy$KBAVG_mean[2], 1), " ± ", round(PD_tydy$KBAVG_sd[2], 1), sep = '')
#     AVROH_pvalue <- signif(summary(model3_Onset)$coef[2, 4], 3)
#
#     # NROH results
#     NROH_EOPD <- paste(round(PD_tydy$NSEG_mean[1], 1), " ± ", round(PD_tydy$NSEG_sd[1], 1), sep = '')
#     NROH_LOPD <- paste(round(PD_tydy$NSEG_mean[2], 1), " ± ", round(PD_tydy$NSEG_sd[2], 1), sep = '')
#     NROH_pvalue <- signif(summary(model1_Onset)$coef[2, 4], 3)
#
#     # FROH results
#     FROH_EOPD <- paste(round(PD_tydy$FROH_mean[1], 4), " ± ", signif(PD_tydy$FROH_sd[1], 2), sep = '')
#     FROH_LOPD <- paste(round(PD_tydy$FROH_mean[2], 4), " ± ", signif(PD_tydy$FROH_sd[2], 2), sep = '')
#     FROH_pvalue <- signif(summary(model4_Onset)$coef[2, 4], 3)
#
#     # Consolidate results into a row
#     row <- c(ancestries[ANC], EOPD_LOPD, SROH_EOPD, SROH_LOPD, SROH_pvalue,
#              AVROH_EOPD, AVROH_LOPD, AVROH_pvalue, NROH_EOPD, NROH_LOPD, NROH_pvalue,
#              FROH_EOPD, FROH_LOPD, FROH_pvalue)
#
#     # Append the row to the results dataframe
#     results <- rbind(results, row)
# }
#
# # Assign column names to the results dataframe
# colnames(results) <- c("Ancestries", "EOPD_LOPD", "SROH_EOPD", "SROH_LOPD", "SROH_pvalue",
#                        "AVROH_EOPD", "AVROH_LOPD", "AVROH_pvalue", "NROH_EOPD", "NROH_LOPD",
#                        "NROH_pvalue", "FROH_EOPD", "FROH_LOPD", "FROH_pvalue")
#
# # Write the results to a file
# fwrite(results, "Pvalues_regression_model_earlyVSlate_nonRecessive.txt")
#
# # Display results
# results
# Out:
#   Ancestries   EOPD_LOPD         SROH_EOPD         SROH_LOPD SROH_pvalue
# 1        AAC    21 (128)  8245.1 ± 15765.5  5091.8 ± 16488.7      0.0408
# 2        AFR    21 (137) 25525.3 ± 58858.6  11611.8 ± 8644.8      0.0746
# 3         AJ    83 (719) 20847.5 ± 17799.5 22962.5 ± 27350.7       0.905
# 4        AMR    91 (163) 19517.8 ± 40595.9 13149.9 ± 20924.2        0.09
# 5        CAS     53 (57)    9192.6 ± 20794   5803.5 ± 6784.5       0.376
# 6        EAS   243 (455)   5370.4 ± 8016.6   4759.6 ± 6072.4       0.151
# 7        EUR 1042 (6400)    6722.8 ± 11972   6439.5 ± 8133.1      0.0568
# 8        MDE    31 (128) 53929.1 ± 66341.1   23066 ± 35760.3       0.826
# 9        SAS     22 (40) 11189.9 ± 12058.8 15590.1 ± 29727.7       0.848
#        AVROH_EOPD      AVROH_LOPD AVROH_pvalue   NROH_EOPD NROH_LOPD
# 1 2240.1 ± 1401.7 1707.4 ± 1304.1       0.0168     2.6 ± 4 1.8 ± 2.6
# 2    2509 ± 802.2  2312.5 ± 820.5        0.105  7.3 ± 11.1 4.7 ± 3.3
# ...

# %% [markdown]
# ## Suppl. Table 9 - Linear regression of ROH and PD AOO (excluding recessive genes)

# %%
# %%R
#
# # Define list of ancestries to analyze
# ancestries <- c("AAC", "AFR", "AJ" ,"AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Initialize empty dataframes to store results
# results <- data.frame(NULL)
#
# # Loop through each ancestry for analysis
# for (ANC in 1:length(ancestries)) {
#
#     # Load the ROH data with FROH values for the current ancestry
#     data <- fread(paste0(ancestries[ANC], "_ROH_nonRecessive_withFROH.hom.indiv"), header = TRUE)
#
#     # Recode cases (PHE == 1) and controls (PHE == 0), and remove missing values (-9)
#     dat <- data[data$PHE != -9, ]
#     dat$PHE <- dat$PHE - 1  # Recode PHE so that cases = 1 and controls = 0
#
#     # Load covariates and merge with ROH data
#     cov <- fread(paste0(ancestries[ANC], "_COVAR.txt"), header = TRUE)
#     merged <- merge(dat, cov, by = "IID")
#
#     # Impute missing age values using the mean age
#     merged_impute_age <- merged
#     merged_impute_age[is.na(merged$age),]$age <- round(mean(merged$age, na.rm = TRUE), 0)
#
#     # Subset only Parkinson's disease cases (PHE == 1)
#     PD_cases <- subset(merged_impute_age, PHE == 1)
#
#     # Compute mean and standard deviation for each parameter (NSEG, KB, KBAVG, FROH)
#     PD_tydy <- PD_cases %>%
#         summarise(Number = n(),
#                   NSEG_mean = mean(NSEG), KB_mean = mean(KB), KBAVG_mean = mean(KBAVG),
#                   NSEG_sd = sd(NSEG), KB_sd = sd(KB, na.rm = TRUE), KBAVG_sd = sd(KBAVG, na.rm = TRUE),
#                   FROH_mean = mean(FROH, na.rm = TRUE), FROH_sd = sd(FROH, na.rm = TRUE))
#
#     # Perform linear regressions for AOO against each ROH metric
#     model1_Onset <- lm(AOO ~ NSEG + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = PD_cases)
#     model2_Onset <- lm(AOO ~ KB + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = PD_cases)
#     model3_Onset <- lm(AOO ~ KBAVG + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = PD_cases)
#     model4_Onset <- lm(AOO ~ FROH + PC1 + PC2 + PC3 + PC4 + PC5 + SEX + age, data = PD_cases)
#
#     # Format results for each ROH metric
#     # SROH (Sum of ROH lengths)
#     SROH_cases <- paste(round(PD_tydy$KB_mean[1], 1), " ± ", round(PD_tydy$KB_sd[1], 1), sep = '')
#     SROH_beta <- signif(summary(model2_Onset)$coef[2, 1], 3)
#     SROH_pvalue <- signif(summary(model2_Onset)$coef[2, 4], 3)
#
#     # AVROH (Average ROH length)
#     AVROH_cases <- paste(round(PD_tydy$KBAVG_mean[1], 1), " ± ", round(PD_tydy$KBAVG_sd[1], 1), sep = '')
#     AVROH_beta <- signif(summary(model3_Onset)$coef[2, 1], 3)
#     AVROH_pvalue <- signif(summary(model3_Onset)$coef[2, 4], 3)
#
#     # NROH (Number of ROH segments)
#     NROH_cases <- paste(round(PD_tydy$NSEG_mean[1], 1), " ± ", round(PD_tydy$NSEG_sd[1], 1), sep = '')
#     NROH_beta <- signif(summary(model1_Onset)$coef[2, 1], 3)
#     NROH_pvalue <- signif(summary(model1_Onset)$coef[2, 4], 3)
#
#     # FROH (Genomic inbreeding coefficient)
#     FROH_cases <- paste(round(PD_tydy$FROH_mean[1], 4), " ± ", signif(PD_tydy$FROH_sd[1], 2), sep = '')
#     FROH_beta <- signif(summary(model4_Onset)$coef[2, 1], 3)
#     FROH_pvalue <- signif(summary(model4_Onset)$coef[2, 4], 3)
#
#     # Consolidate results for the current ancestry
#     row <- c(ancestries[ANC], SROH_cases, SROH_beta, SROH_pvalue,
#              AVROH_cases, AVROH_beta, AVROH_pvalue,
#              NROH_cases, NROH_beta, NROH_pvalue,
#              FROH_cases, FROH_beta, FROH_pvalue)
#
#     # Append the row to the results dataframe
#     results <- rbind(results, row)
# }
#
# # Assign column names to the results dataframe
# colnames(results) <- c("Ancestry", "SROH_cases", "SROH_beta", "SROH_pvalue",
#                        "AVROH_cases", "AVROH_beta", "AVROH_pvalue",
#                        "NROH_cases", "NROH_beta", "NROH_pvalue",
#                        "FROH_cases", "FROH_beta", "FROH_pvalue")
#
# # Write the results to a file
# fwrite(results, "Pvalues_regression_model_AOO_nonRecessive.txt")
#
# # Display the results dataframe
# results
# Out:
#   Ancestry        SROH_cases SROH_beta SROH_pvalue     AVROH_cases AVROH_beta
# 1      AAC  6330.5 ± 15828.5  7.86e-06       0.793 1815.6 ± 1353.4  -0.000791
# 2      AFR  9814.6 ± 13786.7  1.54e-05        0.43  2252.7 ± 858.6  -0.000254
# 3       AJ 22579.8 ± 25805.7 -4.41e-06       0.628  2878.5 ± 869.3   0.000476
# 4      AMR 15143.2 ± 28321.4 -5.54e-05    0.000368 2302.8 ± 1236.3   -0.00088
# 5      CAS 13651.4 ± 34036.4  -2.8e-05       0.554  1885.2 ± 840.7    0.00023
# 6      EAS   5187.5 ± 7880.2 -2.08e-05        0.62  1735.7 ± 798.8   0.000301
# 7      EUR   6389.6 ± 8048.7 -2.02e-05      0.0292  1907.8 ± 730.3  -6.24e-05
# 8      MDE 25964.3 ± 41064.9 -5.94e-06       0.612    2049.4 ± 737   0.000772
# 9      SAS 12647.6 ± 21865.5 -7.16e-05       0.282  1995.5 ± 680.6   0.000448
#   AVROH_pvalue  NROH_cases NROH_beta NROH_pvalue      FROH_cases FROH_beta
# 1       0.0355   2.1 ± 3.1   -0.0131       0.939 0.0022 ± 0.0055      22.7
# ...

# %% [markdown]
# # ROH Enrichment in Cases

# %% [markdown]
# ##  Table 4 - ROH overlapping PD genes

# %%
# %%capture
# %%bash

# Set the working directory
WORK_DIR='/home/jupyter/ROH_plots/'
cd $WORK_DIR

# Loop through each ancestry to process ROH overlap files
for ANC in AAC AFR AJ AMR CAS EAS EUR MDE SAS; do
    # Filter for control group data
    cat ${ANC}_ROH.hom.overlap | grep 'CON' | awk -F' ' '{if($4 != "-9")print}' > ${ANC}_ROH.hom.overlap.CON.txt
    
    # Filter for case group data (excluding CON and UNION, clean invalid data)
    cat ${ANC}_ROH.hom.overlap | grep -v 'CON' | grep -v 'UNION' | awk -F' ' '{if($4 != "-9")print}' | grep -v 'NA' > ${ANC}_ROH.hom.overlap.clean.txt
    
    # Use Perl script to map ROH overlaps to gene list and output PD genes file
    perl post_plink_ROH_mapping.pl ${ANC}_ROH.hom.overlap.clean.txt ${ANC}_ROH.hom.overlap.CON.txt geneList.txt ${ANC}_ROH.hom.overlap.CON.PDgenes.txt
done

# %%
# %%bash
#
# # Create ancestry_cases_controls.txt dynamically
# WORK_DIR='/home/jupyter/ROH_plots/'
# cd $WORK_DIR
#
# # Print the header for the ancestry_cases_controls table
# echo -e "Ancestry\tCases\tControls" > ancestry_cases_controls.txt
#
# # Iterate through each ancestry and count cases and controls
# for ANC in AAC AFR AJ AMR CAS EAS EUR MDE SAS; do
#     # Count the number of cases (phenotype = 2)
#     cases=$(cat ${ANC}_ROH.hom.indiv | awk -F' ' '{ if($3 == "2") print }' | wc -l)
#
#     # Count the number of controls (phenotype = 1)
#     controls=$(cat ${ANC}_ROH.hom.indiv | awk -F' ' '{ if($3 == "1") print }' | wc -l)
#
#     # Append the result to the ancestry_cases_controls file
#     echo -e "${ANC}\t${cases}\t${controls}" >> ancestry_cases_controls.txt
# done

# %%
# %%R
#
# library(data.table) # For fread() and fwrite()
# library(stringr)    # For str_split()
#
# # Define ancestries
# ancestries <- c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS")
#
# # Load ancestry cases/controls data
# ancestry_cases_controls <- fread("ancestry_cases_controls.txt", header = TRUE)
#
# # Loop through each ancestry
# for (ANC in 1:length(ancestries)) {
#
#   # Load the ROH data for the current ancestry
#   ROH <- fread(paste0(ancestries[ANC], "_ROH.hom.overlap.CON.PDgenes.txt"), header = TRUE)
#
#   # Split 'case_to_control' into cases and controls
#   ROH[, c("case", "control") := tstrsplit(case_to_control, ":", type.convert = TRUE)]
#
#   # Convert cases and controls to numeric
#   ROH[, `:=`(NcasesWithROHs = as.numeric(case),
#              NcontrolsWithROHs = as.numeric(control))]
#
#   # Get total cases and controls for the ancestry
#   total_cases <- ancestry_cases_controls[Ancestry == ancestries[ANC], Cases]
#   total_controls <- ancestry_cases_controls[Ancestry == ancestries[ANC], Controls]
#
#   # Add additional columns (in separate steps to avoid referencing undefined columns)
#   ROH[, caseN := NcasesWithROHs]
#   ROH[, controlN := NcontrolsWithROHs]
#   ROH[, combinedN := caseN + controlN]
#   ROH[, propCases := caseN / total_cases]
#   ROH[, propControls := controlN / total_controls]
#
#   # Initialize a p-value column
#   ROH[, P := NA_real_]
#
#   # Perform proportion tests for each row
#   for (i in 1:nrow(ROH)) {
#     test_result <- prop.test(
#       x = c(ROH$NcasesWithROHs[i], ROH$NcontrolsWithROHs[i]),
#       n = c(total_cases, total_controls)
#     )
#     ROH$P[i] <- test_result$p.value
#   }
#
#   # Identify case-enriched ROHs
#   ROH[, caseEnriched := ifelse(propCases > propControls, 1, 0)]
#
#   # Save the full ROH data
#   fwrite(ROH, paste0(ancestries[ANC], "_ROH_all.txt"))
#
#   # Subset to case-enriched ROHs with a total count >= 1
#   ROH_subsetted <- ROH[combinedN >= 1 & caseEnriched == 1]
#
#   # Check for zero genes before applying Bonferroni correction
#   Ngenes <- nrow(ROH_subsetted)
#   if (Ngenes > 0) {
#     ROH_subsetted[, passMultiTest := ifelse(P <= (0.05 / Ngenes), 1, 0)]
#   } else {
#     ROH_subsetted[, passMultiTest := 0]
#   }
#
#   # Save the subset of case-enriched ROHs
#   fwrite(ROH_subsetted, paste0(ancestries[ANC], "_ROH_caseEnriched.txt"))
# }
# Out:
# In addition: There were 50 or more warnings (use warnings() to see the first 50)

# %%
# %%bash
#
# WORK_DIR='/home/jupyter/ROH_plots/'
# cd $WORK_DIR
#
# # Loop through all ancestries
# for ANC in AAC AFR AJ AMR CAS EAS EUR MDE SAS; do
#     {
#         # Print the current ancestry being processed
#         printf "${ANC}\n"
#
#         # Count the number of ROH overlapping PD genes, excluding the header
#         printf "Number of ROH overlapping PD genes: "
#         cat ${ANC}_ROH.hom.overlap.CON.PDgenes.txt | sed 1d | wc -l
#
#         # Count the number of ROH enriched in cases, excluding the header
#         printf "Number of ROH enriched in Cases: "
#         cat ${ANC}_ROH_caseEnriched.txt | sed 1d | wc -l
#
#         # Count the number of ROH with p-value < 0.05, ensuring numeric comparison
#         printf "Number of ROH with p < 0.05: "
#         cat ${ANC}_ROH_caseEnriched.txt | sed 1d | awk -F',' '{if ($22 < 0.05) print}' | wc -l
#
#         # Count the number of ROH that pass Bonferroni correction
#         printf "Number of ROH that Pass Bonferroni: "
#         cat ${ANC}_ROH_caseEnriched.txt | cut -d',' -f27 | sed 1d | { grep -c '1' || true; }
#
#         # Print a blank line for separation
#         printf "\n"
#     };
# done
# Out:
# AAC
# Number of ROH overlapping PD genes: 69
# Number of ROH enriched in Cases: 43
# Number of ROH with p < 0.05: 43
# Number of ROH that Pass Bonferroni: 0
#
# AFR
# Number of ROH overlapping PD genes: 256
# Number of ROH enriched in Cases: 164
# Number of ROH with p < 0.05: 164
# Number of ROH that Pass Bonferroni: 0
#
# AJ
# Number of ROH overlapping PD genes: 436
# Number of ROH enriched in Cases: 25
# Number of ROH with p < 0.05: 25
# Number of ROH that Pass Bonferroni: 0
#
# AMR
# Number of ROH overlapping PD genes: 107
# Number of ROH enriched in Cases: 56
# Number of ROH with p < 0.05: 53
# Number of ROH that Pass Bonferroni: 0
#
# CAS
# Number of ROH overlapping PD genes: 128
# Number of ROH enriched in Cases: 61
# Number of ROH with p < 0.05: 60
# Number of ROH that Pass Bonferroni: 0
#
# EAS
# Number of ROH overlapping PD genes: 277
# Number of ROH enriched in Cases: 77
# Number of ROH with p < 0.05: 77
# Number of ROH that Pass Bonferroni: 0
#
# EUR
# ...

# %% [markdown]
# # Summary figures for presentations

# %% [markdown]
# ## For homozygosity mapping results

# %% [markdown]
# ### For inbred results

# %%
# %%R
#
# # Create a sample data frame with different ROH metrics by ancestry
# data <- data.frame(
#   Ancestry = c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS"),  # Ancestry groups
#   Cases = c(6, 13, 49, 20, 15, 10, 75, 42, 8),                                 # Number of cases
#   ROHs_inbred = c(3, 1, 10, 86, 17, 2, 1, 298, 2),                             # ROHs in inbred regions
#   ROHs_PD_genes = c(45, 125, 122, 46, 93, 100, 145, 68, 67),                   # ROHs in PD genes
#   ROHs_inbred_PD = c(18, 68, 112, 38, 68, 38, 130, 63, 30),                    # Inbred ROHs in PD genes
#   ROHs_PD_Bonferroni = c(9, 19, 15, 2, 13, 14, 93, 0, 2)                       # ROHs in PD genes passing Bonferroni correction
# )
#
# # Reshape the data to long format for easier plotting with ggplot2
# melted_data <- melt(data, id.vars = "Ancestry")
#
# # Create a grouped bar chart using ggplot
# ggplot(melted_data, aes(x = Ancestry, y = value, fill = variable)) +  # Set aesthetics
#   geom_bar(stat = "identity", position = "dodge") +                   # Use bars with identity stat, dodge for grouping
#   labs(title = "Grouped Bar Chart of ROH Metrics by Ancestry",         # Add plot title
#        x = "Ancestry",                                                 # Label for x-axis
#        y = "Count",                                                    # Label for y-axis
#        fill = "Metric") +                                              # Legend title
#   theme_minimal() +                                                    # Apply a clean theme
#   theme(axis.text.x = element_text(angle = 45, hjust = 1))             # Rotate x-axis labels for better readability

# %%
# %%R
#
# # Sample data containing various ROH metrics by ancestry
# data <- data.frame(
#   Ancestry = c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS"),  # Ancestry groups
#   Cases = c(6, 13, 49, 20, 15, 10, 75, 42, 8),                                 # Number of cases
#   ROHs_inbred_only = c(3, 1, 10, 86, 17, 2, 1, 298, 2),                        # ROHs in inbred regions
#   ROHs_pass_Bonferroni = c(51, 128, 56, 7, 66, 118, 851, 0, 6),                # ROHs passing Bonferroni correction
#   ROHs_PD_genes = c(45, 125, 122, 46, 93, 100, 145, 68, 67),                   # ROHs in Parkinson's disease (PD) genes
#   ROHs_inbred_PD_genes = c(18, 68, 112, 38, 68, 38, 130, 63, 30),              # Inbred ROHs in PD genes
#   ROHs_PD_genes_pass_Bonferroni = c(9, 19, 15, 2, 13, 14, 93, 0, 2)            # ROHs in PD genes passing Bonferroni correction
# )
#
# # Melt the data into long format for easier plotting with ggplot
# melted_data <- melt(data, id.vars = "Ancestry")
#
# # Apply a logarithmic transformation to the data values to handle large ranges
# melted_data$value <- log1p(melted_data$value)  # log1p() handles log(1 + value) to avoid log(0) issues
#
# # Create the heatmap plot
# p <- ggplot(melted_data, aes(x = variable, y = Ancestry, fill = value)) +  # Set aesthetics: x-axis is 'variable', y-axis is 'Ancestry', fill is 'value'
#   geom_tile() +                                                            # Create heatmap tiles
#   geom_text(aes(label = sprintf("%.1f", expm1(value))), color = "black", size = 4) +  # Add values to the tiles, reversing the log transformation
#   scale_fill_gradient(low = "white", high = "#098dc3ff") +                  # Set color gradient from white to blue
#   labs(title = "Heatmap of Homozygosity Mapping by Ancestry for Inbred Individuals",  # Title
#        x = "Metric",                                                        # x-axis label
#        y = "Ancestry",                                                      # y-axis label
#        fill = "Count") +                                                    # Legend title
#   theme_minimal() +                                                         # Apply a minimal theme
#   theme(axis.text.x = element_text(angle = 45, hjust = 1, size = 12),       # Rotate and increase size of x-axis text
#         axis.text.y = element_text(size = 12),                              # Increase y-axis text size
#         plot.title = element_text(size = 14, face = "bold"),                # Set larger, bold title
#         legend.text = element_text(size = 10),                              # Set larger legend text
#         legend.title = element_text(size = 12))                             # Set larger legend title
#
# # Save the plot as a PNG file with high resolution
# ggsave("heatmap_inbred.png", plot = p, width = 10, height = 8, dpi = 300)
#
# # Output the heatmap plot
# p

# %% [markdown]
# ### For EOPD results

# %%
# %%R
#
# # Sample data representing different ancestry groups and their corresponding ROH metrics
# data <- data.frame(
#   Ancestry = c("AAC", "AFR", "AJ", "AMR", "CAS", "EAS", "EUR", "MDE", "SAS"),
#   EOPD_cases = c(21, 21, 83, 91, 53, 243, 1042, 31, 22),  # Number of EOPD cases
#   ROHs_EOPD_only = c(0, 0, 3, 60, 0, 0, 3, 175, 0),  # ROHs found in EOPD only
#   ROHs_pass_Bonferroni = c(53, 16, 0, 0, 0, 0, 1, 0, 0),  # ROHs passing Bonferroni correction
#   ROHs_PD_genes = c(40, 117, 107, 42, 77, 25, 136, 33, 84),  # ROHs overlapping PD genes
#   ROHs_EOPD_PD_genes = c(3, 34, 54, 33, 25, 2, 65, 30, 13),  # ROHs in EOPD and PD genes
#   ROHs_PD_genes_pass_Bonferroni = c(0, 16, 0, 0, 0, 0, 1, 0, 0)  # ROHs in PD genes passing Bonferroni
# )
#
# # Melt the data for easier plotting, converting from wide to long format
# melted_data <- melt(data, id.vars = "Ancestry")
#
# # Apply a logarithmic transformation to handle large value differences
# melted_data$value <- log1p(melted_data$value)
#
# # Create a heatmap showing various ROH metrics by ancestry
# p <- ggplot(melted_data, aes(x = variable, y = Ancestry, fill = value)) +
#   geom_tile() +  # Create a heatmap using tiles
#   geom_text(aes(label = sprintf("%.1f", expm1(value))), color = "black", size = 4) +  # Display the original values inside the tiles
#   scale_fill_gradient(low = "white", high = "#098dc3ff") +  # Set a color gradient from white to blue
#   labs(title = "Heatmap of Homozygosity Mapping by Ancestry for EOPD Cases",
#        x = "Metric",
#        y = "Ancestry",
#        fill = "Count") +  # Customize axis labels and color legend
#   theme_minimal() +  # Use a minimal theme for a clean look
#   theme(axis.text.x = element_text(angle = 45, hjust = 1, size = 12),  # Rotate and size x-axis labels
#         axis.text.y = element_text(size = 12),  # Size y-axis labels
#         plot.title = element_text(size = 14, face = "bold"),  # Bold the title
#         legend.text = element_text(size = 10),  # Size legend text
#         legend.title = element_text(size = 12))  # Size the legend title
#
# # Save the heatmap to a PNG file with high resolution
# ggsave("heatmap_EOPD.png", plot = p, width = 10, height = 8, dpi = 300)
#
# # Output the heatmap plot
# p
